# %% [markdown]
# # Libraries

# %%
from pathlib import Path

from anomalib.data.utils import read_image
from anomalib.deploy import OpenVINOInferencer
from pytorch_lightning import Trainer
from pytorch_lightning.callbacks import ModelCheckpoint

import os
from PIL import Image

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Converting from JPG to png

# %%
source_directory = "./pcb3/Data/Images/Anomaly/"
destination_directory = "./pcb3/anomaly_png/"

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_directory):
    os.makedirs(destination_directory)

# Iterate over the files in the source directory
for filename in os.listdir(source_directory):
    if filename.endswith(".JPG"):
        # Open the image file
        image_path = os.path.join(source_directory, filename)
        image = Image.open(image_path)

        # Convert and save the image as .png in the destination directory
        new_filename = os.path.splitext(filename)[0] + ".png"
        destination_path = os.path.join(destination_directory, new_filename)
        image.save(destination_path, "PNG")

        print(f"Converted {filename} to {new_filename} and saved to {destination_directory}")
# Out:
# Converted 000.JPG to 000.png and saved to ./pcb3/anomaly_png/
# Converted 001.JPG to 001.png and saved to ./pcb3/anomaly_png/
# Converted 002.JPG to 002.png and saved to ./pcb3/anomaly_png/
# Converted 003.JPG to 003.png and saved to ./pcb3/anomaly_png/
# Converted 004.JPG to 004.png and saved to ./pcb3/anomaly_png/
# Converted 005.JPG to 005.png and saved to ./pcb3/anomaly_png/
# Converted 006.JPG to 006.png and saved to ./pcb3/anomaly_png/
# Converted 007.JPG to 007.png and saved to ./pcb3/anomaly_png/
# Converted 008.JPG to 008.png and saved to ./pcb3/anomaly_png/
# Converted 009.JPG to 009.png and saved to ./pcb3/anomaly_png/
# Converted 010.JPG to 010.png and saved to ./pcb3/anomaly_png/
# Converted 011.JPG to 011.png and saved to ./pcb3/anomaly_png/
# Converted 012.JPG to 012.png and saved to ./pcb3/anomaly_png/
# Converted 013.JPG to 013.png and saved to ./pcb3/anomaly_png/
# Converted 014.JPG to 014.png and saved to ./pcb3/anomaly_png/
# Converted 015.JPG to 015.png and saved to ./pcb3/anomaly_png/
# Converted 016.JPG to 016.png and saved to ./pcb3/anomaly_png/
# Converted 017.JPG to 017.png and saved to ./pcb3/anomaly_png/
# Converted 018.JPG to 018.png and saved to ./pcb3/anomaly_png/
# Converted 019.JPG to 019.png and saved to ./pcb3/anomaly_png/
# Converted 020.JPG to 020.png and saved to ./pcb3/anomaly_png/
# Converted 021.JPG to 021.png and saved to ./pcb3/anomaly_png/
# Converted 022.JPG to 022.png and saved to ./pcb3/anomaly_png/
# Converted 023.JPG to 023.png and saved to ./pcb3/anomaly_png/
# Converted 024.JPG to 024.png and saved to ./pcb3/anomaly_png/
# Converted 025.JPG to 025.png and saved to ./pcb3/anomaly_png/
# Converted 026.JPG to 026.png and saved to ./pcb3/anomaly_png/
# Converted 027.JPG to 027.png and saved to ./pcb3/anomaly_png/
# Converted 028.JPG to 028.png and saved to ./pcb3/anomaly_png/
# Converted 029.JPG to 029.png and saved to ./pcb3/anomaly_png/
# Converted 030.JPG to 030.png and saved to ./pcb3/anomaly_png/
# Converted 031.JPG to 031.png and saved to ./pcb3/anomaly_png/
# Converted 032.JPG to 032.png and saved to ./pcb3/anomaly_png/
# Converted 033.JPG to 033.png and saved to ./pcb3/anomaly_png/
# Converted 034.JPG to 034.png and saved to ./pcb3/anomaly_png/
# Converted 035.JPG to 035.png and saved to ./pcb3/anomaly_png/
# Converted 036.JPG to 036.png and saved to ./pcb3/anomaly_png/
# Converted 037.JPG to 037.png and saved to ./pcb3/anomaly_png/
# Converted 038.JPG to 038.png and saved to ./pcb3/anomaly_png/
# Converted 039.JPG to 039.png and saved to ./pcb3/anomaly_png/
# Converted 040.JPG to 040.png and saved to ./pcb3/anomaly_png/
# Converted 041.JPG to 041.png and saved to ./pcb3/anomaly_png/
# Converted 042.JPG to 042.png and saved to ./pcb3/anomaly_png/
# Converted 043.JPG to 043.png and saved to ./pcb3/anomaly_png/
# Converted 044.JPG to 044.png and saved to ./pcb3/anomaly_png/
# Converted 045.JPG to 045.png and saved to ./pcb3/anomaly_png/
# Converted 046.JPG to 046.png and saved to ./pcb3/anomaly_png/
# Converted 047.JPG to 047.png and saved to ./pcb3/anomaly_png/
# Converted 048.JPG to 048.png and saved to ./pcb3/anomaly_png/
# Converted 049.JPG to 049.png and saved to ./pcb3/anomaly_png/
# Converted 050.JPG to 050.png and saved to ./pcb3/anomaly_png/
# Converted 051.JPG to 051.png and saved to ./pcb3/anomaly_png/
# Converted 052.JPG to 052.png and saved to ./pcb3/anomaly_png/
# Converted 053.JPG to 053.png and saved to ./pcb3/anomaly_png/
# Converted 054.JPG to 054.png and saved to ./pcb3/anomaly_png/
# Converted 055.JPG to 055.png and saved to ./pcb3/anomaly_png/
# Converted 056.JPG to 056.png and saved to ./pcb3/anomaly_png/
# Converted 057.JPG to 057.png and saved to ./pcb3/anomaly_png/
# Converted 058.JPG to 058.png and saved to ./pcb3/anomaly_png/
# Converted 059.JPG to 059.png and saved to ./pcb3/anomaly_png/
# Converted 060.JPG to 060.png and saved to ./pcb3/anomaly_png/
# Converted 061.JPG to 061.png and saved to ./pcb3/anomaly_png/
# Converted 062.JPG to 062.png and saved to ./pcb3/anomaly_png/
# Converted 063.JPG to 063.png and saved to ./pcb3/anomaly_png/
# Converted 064.JPG to 064.png and saved to ./pcb3/anomaly_png/
# Converted 065.JPG to 065.png and saved to ./pcb3/anomaly_png/
# Converted 066.JPG to 066.png and saved to ./pcb3/anomaly_png/
# Converted 067.JPG to 067.png and saved to ./pcb3/anomaly_png/
# Converted 068.JPG to 068.png and saved to ./pcb3/anomaly_png/
# Converted 069.JPG to 069.png and saved to ./pcb3/anomaly_png/
# Converted 070.JPG to 070.png and saved to ./pcb3/anomaly_png/
# Converted 071.JPG to 071.png and saved to ./pcb3/anomaly_png/
# Converted 072.JPG to 072.png and saved to ./pcb3/anomaly_png/
# Converted 073.JPG to 073.png and saved to ./pcb3/anomaly_png/
# Converted 074.JPG to 074.png and saved to ./pcb3/anomaly_png/
# Converted 075.JPG to 075.png and saved to ./pcb3/anomaly_png/
# Converted 076.JPG to 076.png and saved to ./pcb3/anomaly_png/
# Converted 077.JPG to 077.png and saved to ./pcb3/anomaly_png/
# Converted 078.JPG to 078.png and saved to ./pcb3/anomaly_png/
# Converted 079.JPG to 079.png and saved to ./pcb3/anomaly_png/
# Converted 080.JPG to 080.png and saved to ./pcb3/anomaly_png/
# Converted 081.JPG to 081.png and saved to ./pcb3/anomaly_png/
# Converted 082.JPG to 082.png and saved to ./pcb3/anomaly_png/
# Converted 083.JPG to 083.png and saved to ./pcb3/anomaly_png/
# Converted 084.JPG to 084.png and saved to ./pcb3/anomaly_png/
# Converted 085.JPG to 085.png and saved to ./pcb3/anomaly_png/
# Converted 086.JPG to 086.png and saved to ./pcb3/anomaly_png/
# Converted 087.JPG to 087.png and saved to ./pcb3/anomaly_png/
# Converted 088.JPG to 088.png and saved to ./pcb3/anomaly_png/
# Converted 089.JPG to 089.png and saved to ./pcb3/anomaly_png/
# Converted 090.JPG to 090.png and saved to ./pcb3/anomaly_png/
# Converted 091.JPG to 091.png and saved to ./pcb3/anomaly_png/
# Converted 092.JPG to 092.png and saved to ./pcb3/anomaly_png/
# Converted 093.JPG to 093.png and saved to ./pcb3/anomaly_png/
# Converted 094.JPG to 094.png and saved to ./pcb3/anomaly_png/
# Converted 095.JPG to 095.png and saved to ./pcb3/anomaly_png/
# Converted 096.JPG to 096.png and saved to ./pcb3/anomaly_png/
# Converted 097.JPG to 097.png and saved to ./pcb3/anomaly_png/
# Converted 098.JPG to 098.png and saved to ./pcb3/anomaly_png/
# Converted 099.JPG to 099.png and saved to ./pcb3/anomaly_png/

# %%
source_directory = "./pcb3/Data/Images/Normal"
destination_directory = "./pcb3/normal_png/"

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_directory):
    os.makedirs(destination_directory)

# Iterate over the files in the source directory
for filename in os.listdir(source_directory):
    if filename.endswith(".JPG"):
        # Open the image file
        image_path = os.path.join(source_directory, filename)
        image = Image.open(image_path)

        # Convert and save the image as .png in the destination directory
        new_filename = os.path.splitext(filename)[0] + ".png"
        destination_path = os.path.join(destination_directory, new_filename)
        image.save(destination_path, "PNG")

        print(f"Converted {filename} to {new_filename} and saved to {destination_directory}")
# Out:
# Converted 0000.JPG to 0000.png and saved to ./pcb3/normal_png/
# Converted 0001.JPG to 0001.png and saved to ./pcb3/normal_png/
# Converted 0002.JPG to 0002.png and saved to ./pcb3/normal_png/
# Converted 0003.JPG to 0003.png and saved to ./pcb3/normal_png/
# Converted 0004.JPG to 0004.png and saved to ./pcb3/normal_png/
# Converted 0005.JPG to 0005.png and saved to ./pcb3/normal_png/
# Converted 0006.JPG to 0006.png and saved to ./pcb3/normal_png/
# Converted 0007.JPG to 0007.png and saved to ./pcb3/normal_png/
# Converted 0008.JPG to 0008.png and saved to ./pcb3/normal_png/
# Converted 0009.JPG to 0009.png and saved to ./pcb3/normal_png/
# Converted 0010.JPG to 0010.png and saved to ./pcb3/normal_png/
# Converted 0011.JPG to 0011.png and saved to ./pcb3/normal_png/
# Converted 0012.JPG to 0012.png and saved to ./pcb3/normal_png/
# Converted 0013.JPG to 0013.png and saved to ./pcb3/normal_png/
# Converted 0014.JPG to 0014.png and saved to ./pcb3/normal_png/
# Converted 0015.JPG to 0015.png and saved to ./pcb3/normal_png/
# Converted 0016.JPG to 0016.png and saved to ./pcb3/normal_png/
# Converted 0017.JPG to 0017.png and saved to ./pcb3/normal_png/
# Converted 0018.JPG to 0018.png and saved to ./pcb3/normal_png/
# Converted 0019.JPG to 0019.png and saved to ./pcb3/normal_png/
# Converted 0020.JPG to 0020.png and saved to ./pcb3/normal_png/
# Converted 0021.JPG to 0021.png and saved to ./pcb3/normal_png/
# Converted 0022.JPG to 0022.png and saved to ./pcb3/normal_png/
# Converted 0023.JPG to 0023.png and saved to ./pcb3/normal_png/
# Converted 0024.JPG to 0024.png and saved to ./pcb3/normal_png/
# Converted 0025.JPG to 0025.png and saved to ./pcb3/normal_png/
# Converted 0026.JPG to 0026.png and saved to ./pcb3/normal_png/
# Converted 0027.JPG to 0027.png and saved to ./pcb3/normal_png/
# Converted 0028.JPG to 0028.png and saved to ./pcb3/normal_png/
# Converted 0029.JPG to 0029.png and saved to ./pcb3/normal_png/
# Converted 0030.JPG to 0030.png and saved to ./pcb3/normal_png/
# Converted 0031.JPG to 0031.png and saved to ./pcb3/normal_png/
# Converted 0032.JPG to 0032.png and saved to ./pcb3/normal_png/
# Converted 0033.JPG to 0033.png and saved to ./pcb3/normal_png/
# Converted 0034.JPG to 0034.png and saved to ./pcb3/normal_png/
# Converted 0035.JPG to 0035.png and saved to ./pcb3/normal_png/
# Converted 0036.JPG to 0036.png and saved to ./pcb3/normal_png/
# Converted 0037.JPG to 0037.png and saved to ./pcb3/normal_png/
# Converted 0038.JPG to 0038.png and saved to ./pcb3/normal_png/
# Converted 0039.JPG to 0039.png and saved to ./pcb3/normal_png/
# Converted 0040.JPG to 0040.png and saved to ./pcb3/normal_png/
# Converted 0041.JPG to 0041.png and saved to ./pcb3/normal_png/
# Converted 0042.JPG to 0042.png and saved to ./pcb3/normal_png/
# Converted 0043.JPG to 0043.png and saved to ./pcb3/normal_png/
# Converted 0044.JPG to 0044.png and saved to ./pcb3/normal_png/
# Converted 0045.JPG to 0045.png and saved to ./pcb3/normal_png/
# Converted 0046.JPG to 0046.png and saved to ./pcb3/normal_png/
# Converted 0047.JPG to 0047.png and saved to ./pcb3/normal_png/
# Converted 0048.JPG to 0048.png and saved to ./pcb3/normal_png/
# Converted 0049.JPG to 0049.png and saved to ./pcb3/normal_png/
# Converted 0050.JPG to 0050.png and saved to ./pcb3/normal_png/
# Converted 0051.JPG to 0051.png and saved to ./pcb3/normal_png/
# Converted 0052.JPG to 0052.png and saved to ./pcb3/normal_png/
# Converted 0053.JPG to 0053.png and saved to ./pcb3/normal_png/
# Converted 0054.JPG to 0054.png and saved to ./pcb3/normal_png/
# Converted 0055.JPG to 0055.png and saved to ./pcb3/normal_png/
# Converted 0056.JPG to 0056.png and saved to ./pcb3/normal_png/
# Converted 0057.JPG to 0057.png and saved to ./pcb3/normal_png/
# Converted 0058.JPG to 0058.png and saved to ./pcb3/normal_png/
# Converted 0059.JPG to 0059.png and saved to ./pcb3/normal_png/
# Converted 0060.JPG to 0060.png and saved to ./pcb3/normal_png/
# Converted 0061.JPG to 0061.png and saved to ./pcb3/normal_png/
# Converted 0062.JPG to 0062.png and saved to ./pcb3/normal_png/
# Converted 0063.JPG to 0063.png and saved to ./pcb3/normal_png/
# Converted 0064.JPG to 0064.png and saved to ./pcb3/normal_png/
# Converted 0065.JPG to 0065.png and saved to ./pcb3/normal_png/
# Converted 0066.JPG to 0066.png and saved to ./pcb3/normal_png/
# Converted 0067.JPG to 0067.png and saved to ./pcb3/normal_png/
# Converted 0068.JPG to 0068.png and saved to ./pcb3/normal_png/
# Converted 0069.JPG to 0069.png and saved to ./pcb3/normal_png/
# Converted 0070.JPG to 0070.png and saved to ./pcb3/normal_png/
# Converted 0071.JPG to 0071.png and saved to ./pcb3/normal_png/
# Converted 0072.JPG to 0072.png and saved to ./pcb3/normal_png/
# Converted 0073.JPG to 0073.png and saved to ./pcb3/normal_png/
# Converted 0074.JPG to 0074.png and saved to ./pcb3/normal_png/
# Converted 0075.JPG to 0075.png and saved to ./pcb3/normal_png/
# Converted 0076.JPG to 0076.png and saved to ./pcb3/normal_png/
# Converted 0077.JPG to 0077.png and saved to ./pcb3/normal_png/
# Converted 0078.JPG to 0078.png and saved to ./pcb3/normal_png/
# Converted 0079.JPG to 0079.png and saved to ./pcb3/normal_png/
# Converted 0080.JPG to 0080.png and saved to ./pcb3/normal_png/
# Converted 0081.JPG to 0081.png and saved to ./pcb3/normal_png/
# Converted 0082.JPG to 0082.png and saved to ./pcb3/normal_png/
# Converted 0083.JPG to 0083.png and saved to ./pcb3/normal_png/
# Converted 0084.JPG to 0084.png and saved to ./pcb3/normal_png/
# Converted 0085.JPG to 0085.png and saved to ./pcb3/normal_png/
# Converted 0086.JPG to 0086.png and saved to ./pcb3/normal_png/
# Converted 0087.JPG to 0087.png and saved to ./pcb3/normal_png/
# Converted 0088.JPG to 0088.png and saved to ./pcb3/normal_png/
# Converted 0089.JPG to 0089.png and saved to ./pcb3/normal_png/
# Converted 0090.JPG to 0090.png and saved to ./pcb3/normal_png/
# Converted 0091.JPG to 0091.png and saved to ./pcb3/normal_png/
# Converted 0092.JPG to 0092.png and saved to ./pcb3/normal_png/
# Converted 0093.JPG to 0093.png and saved to ./pcb3/normal_png/
# Converted 0094.JPG to 0094.png and saved to ./pcb3/normal_png/
# Converted 0095.JPG to 0095.png and saved to ./pcb3/normal_png/
# Converted 0096.JPG to 0096.png and saved to ./pcb3/normal_png/
# Converted 0097.JPG to 0097.png and saved to ./pcb3/normal_png/
# Converted 0098.JPG to 0098.png and saved to ./pcb3/normal_png/
# Converted 0099.JPG to 0099.png and saved to ./pcb3/normal_png/
# Converted 0100.JPG to 0100.png and saved to ./pcb3/normal_png/
# Converted 0101.JPG to 0101.png and saved to ./pcb3/normal_png/
# Converted 0102.JPG to 0102.png and saved to ./pcb3/normal_png/
# Converted 0103.JPG to 0103.png and saved to ./pcb3/normal_png/
# Converted 0104.JPG to 0104.png and saved to ./pcb3/normal_png/
# Converted 0105.JPG to 0105.png and saved to ./pcb3/normal_png/
# Converted 0106.JPG to 0106.png and saved to ./pcb3/normal_png/
# Converted 0107.JPG to 0107.png and saved to ./pcb3/normal_png/
# Converted 0108.JPG to 0108.png and saved to ./pcb3/normal_png/
# Converted 0109.JPG to 0109.png and saved to ./pcb3/normal_png/
# Converted 0110.JPG to 0110.png and saved to ./pcb3/normal_png/
# Converted 0111.JPG to 0111.png and saved to ./pcb3/normal_png/
# Converted 0112.JPG to 0112.png and saved to ./pcb3/normal_png/
# Converted 0113.JPG to 0113.png and saved to ./pcb3/normal_png/
# Converted 0114.JPG to 0114.png and saved to ./pcb3/normal_png/
# Converted 0115.JPG to 0115.png and saved to ./pcb3/normal_png/
# Converted 0116.JPG to 0116.png and saved to ./pcb3/normal_png/
# Converted 0117.JPG to 0117.png and saved to ./pcb3/normal_png/
# Converted 0118.JPG to 0118.png and saved to ./pcb3/normal_png/
# Converted 0119.JPG to 0119.png and saved to ./pcb3/normal_png/
# Converted 0120.JPG to 0120.png and saved to ./pcb3/normal_png/
# Converted 0121.JPG to 0121.png and saved to ./pcb3/normal_png/
# Converted 0122.JPG to 0122.png and saved to ./pcb3/normal_png/
# Converted 0123.JPG to 0123.png and saved to ./pcb3/normal_png/
# Converted 0124.JPG to 0124.png and saved to ./pcb3/normal_png/
# Converted 0125.JPG to 0125.png and saved to ./pcb3/normal_png/
# Converted 0126.JPG to 0126.png and saved to ./pcb3/normal_png/
# Converted 0127.JPG to 0127.png and saved to ./pcb3/normal_png/
# Converted 0128.JPG to 0128.png and saved to ./pcb3/normal_png/
# Converted 0129.JPG to 0129.png and saved to ./pcb3/normal_png/
# Converted 0130.JPG to 0130.png and saved to ./pcb3/normal_png/
# Converted 0131.JPG to 0131.png and saved to ./pcb3/normal_png/
# Converted 0132.JPG to 0132.png and saved to ./pcb3/normal_png/
# Converted 0133.JPG to 0133.png and saved to ./pcb3/normal_png/
# Converted 0134.JPG to 0134.png and saved to ./pcb3/normal_png/
# Converted 0135.JPG to 0135.png and saved to ./pcb3/normal_png/
# Converted 0136.JPG to 0136.png and saved to ./pcb3/normal_png/
# Converted 0137.JPG to 0137.png and saved to ./pcb3/normal_png/
# Converted 0138.JPG to 0138.png and saved to ./pcb3/normal_png/
# Converted 0139.JPG to 0139.png and saved to ./pcb3/normal_png/
# Converted 0140.JPG to 0140.png and saved to ./pcb3/normal_png/
# Converted 0141.JPG to 0141.png and saved to ./pcb3/normal_png/
# Converted 0142.JPG to 0142.png and saved to ./pcb3/normal_png/
# Converted 0143.JPG to 0143.png and saved to ./pcb3/normal_png/
# Converted 0144.JPG to 0144.png and saved to ./pcb3/normal_png/
# Converted 0145.JPG to 0145.png and saved to ./pcb3/normal_png/
# Converted 0146.JPG to 0146.png and saved to ./pcb3/normal_png/
# Converted 0147.JPG to 0147.png and saved to ./pcb3/normal_png/
# Converted 0148.JPG to 0148.png and saved to ./pcb3/normal_png/
# Converted 0149.JPG to 0149.png and saved to ./pcb3/normal_png/
# Converted 0150.JPG to 0150.png and saved to ./pcb3/normal_png/
# Converted 0151.JPG to 0151.png and saved to ./pcb3/normal_png/
# Converted 0152.JPG to 0152.png and saved to ./pcb3/normal_png/
# Converted 0153.JPG to 0153.png and saved to ./pcb3/normal_png/
# Converted 0154.JPG to 0154.png and saved to ./pcb3/normal_png/
# Converted 0155.JPG to 0155.png and saved to ./pcb3/normal_png/
# Converted 0156.JPG to 0156.png and saved to ./pcb3/normal_png/
# Converted 0157.JPG to 0157.png and saved to ./pcb3/normal_png/
# Converted 0158.JPG to 0158.png and saved to ./pcb3/normal_png/
# Converted 0159.JPG to 0159.png and saved to ./pcb3/normal_png/
# Converted 0160.JPG to 0160.png and saved to ./pcb3/normal_png/
# Converted 0161.JPG to 0161.png and saved to ./pcb3/normal_png/
# Converted 0162.JPG to 0162.png and saved to ./pcb3/normal_png/
# Converted 0163.JPG to 0163.png and saved to ./pcb3/normal_png/
# Converted 0164.JPG to 0164.png and saved to ./pcb3/normal_png/
# Converted 0165.JPG to 0165.png and saved to ./pcb3/normal_png/
# Converted 0166.JPG to 0166.png and saved to ./pcb3/normal_png/
# Converted 0167.JPG to 0167.png and saved to ./pcb3/normal_png/
# Converted 0168.JPG to 0168.png and saved to ./pcb3/normal_png/
# Converted 0169.JPG to 0169.png and saved to ./pcb3/normal_png/
# Converted 0170.JPG to 0170.png and saved to ./pcb3/normal_png/
# Converted 0171.JPG to 0171.png and saved to ./pcb3/normal_png/
# Converted 0172.JPG to 0172.png and saved to ./pcb3/normal_png/
# Converted 0173.JPG to 0173.png and saved to ./pcb3/normal_png/
# Converted 0174.JPG to 0174.png and saved to ./pcb3/normal_png/
# Converted 0175.JPG to 0175.png and saved to ./pcb3/normal_png/
# Converted 0176.JPG to 0176.png and saved to ./pcb3/normal_png/
# Converted 0177.JPG to 0177.png and saved to ./pcb3/normal_png/
# Converted 0178.JPG to 0178.png and saved to ./pcb3/normal_png/
# Converted 0179.JPG to 0179.png and saved to ./pcb3/normal_png/
# Converted 0180.JPG to 0180.png and saved to ./pcb3/normal_png/
# Converted 0181.JPG to 0181.png and saved to ./pcb3/normal_png/
# Converted 0182.JPG to 0182.png and saved to ./pcb3/normal_png/
# Converted 0183.JPG to 0183.png and saved to ./pcb3/normal_png/
# Converted 0184.JPG to 0184.png and saved to ./pcb3/normal_png/
# Converted 0185.JPG to 0185.png and saved to ./pcb3/normal_png/
# Converted 0186.JPG to 0186.png and saved to ./pcb3/normal_png/
# Converted 0187.JPG to 0187.png and saved to ./pcb3/normal_png/
# Converted 0188.JPG to 0188.png and saved to ./pcb3/normal_png/
# Converted 0189.JPG to 0189.png and saved to ./pcb3/normal_png/
# Converted 0190.JPG to 0190.png and saved to ./pcb3/normal_png/
# Converted 0191.JPG to 0191.png and saved to ./pcb3/normal_png/
# Converted 0192.JPG to 0192.png and saved to ./pcb3/normal_png/
# Converted 0193.JPG to 0193.png and saved to ./pcb3/normal_png/
# Converted 0194.JPG to 0194.png and saved to ./pcb3/normal_png/
# Converted 0195.JPG to 0195.png and saved to ./pcb3/normal_png/
# Converted 0196.JPG to 0196.png and saved to ./pcb3/normal_png/
# Converted 0197.JPG to 0197.png and saved to ./pcb3/normal_png/
# Converted 0198.JPG to 0198.png and saved to ./pcb3/normal_png/
# Converted 0199.JPG to 0199.png and saved to ./pcb3/normal_png/
# Converted 0200.JPG to 0200.png and saved to ./pcb3/normal_png/
# Converted 0201.JPG to 0201.png and saved to ./pcb3/normal_png/
# Converted 0202.JPG to 0202.png and saved to ./pcb3/normal_png/
# Converted 0203.JPG to 0203.png and saved to ./pcb3/normal_png/
# Converted 0204.JPG to 0204.png and saved to ./pcb3/normal_png/
# Converted 0205.JPG to 0205.png and saved to ./pcb3/normal_png/
# Converted 0206.JPG to 0206.png and saved to ./pcb3/normal_png/
# Converted 0207.JPG to 0207.png and saved to ./pcb3/normal_png/
# Converted 0208.JPG to 0208.png and saved to ./pcb3/normal_png/
# Converted 0209.JPG to 0209.png and saved to ./pcb3/normal_png/
# Converted 0210.JPG to 0210.png and saved to ./pcb3/normal_png/
# Converted 0211.JPG to 0211.png and saved to ./pcb3/normal_png/
# Converted 0212.JPG to 0212.png and saved to ./pcb3/normal_png/
# Converted 0213.JPG to 0213.png and saved to ./pcb3/normal_png/
# Converted 0214.JPG to 0214.png and saved to ./pcb3/normal_png/
# Converted 0215.JPG to 0215.png and saved to ./pcb3/normal_png/
# Converted 0216.JPG to 0216.png and saved to ./pcb3/normal_png/
# Converted 0217.JPG to 0217.png and saved to ./pcb3/normal_png/
# Converted 0218.JPG to 0218.png and saved to ./pcb3/normal_png/
# Converted 0219.JPG to 0219.png and saved to ./pcb3/normal_png/
# Converted 0220.JPG to 0220.png and saved to ./pcb3/normal_png/
# Converted 0221.JPG to 0221.png and saved to ./pcb3/normal_png/
# Converted 0222.JPG to 0222.png and saved to ./pcb3/normal_png/
# Converted 0223.JPG to 0223.png and saved to ./pcb3/normal_png/
# Converted 0224.JPG to 0224.png and saved to ./pcb3/normal_png/
# Converted 0225.JPG to 0225.png and saved to ./pcb3/normal_png/
# Converted 0226.JPG to 0226.png and saved to ./pcb3/normal_png/
# Converted 0227.JPG to 0227.png and saved to ./pcb3/normal_png/
# Converted 0228.JPG to 0228.png and saved to ./pcb3/normal_png/
# Converted 0229.JPG to 0229.png and saved to ./pcb3/normal_png/
# Converted 0230.JPG to 0230.png and saved to ./pcb3/normal_png/
# Converted 0231.JPG to 0231.png and saved to ./pcb3/normal_png/
# Converted 0232.JPG to 0232.png and saved to ./pcb3/normal_png/
# Converted 0233.JPG to 0233.png and saved to ./pcb3/normal_png/
# Converted 0234.JPG to 0234.png and saved to ./pcb3/normal_png/
# Converted 0235.JPG to 0235.png and saved to ./pcb3/normal_png/
# Converted 0236.JPG to 0236.png and saved to ./pcb3/normal_png/
# Converted 0237.JPG to 0237.png and saved to ./pcb3/normal_png/
# Converted 0238.JPG to 0238.png and saved to ./pcb3/normal_png/
# Converted 0239.JPG to 0239.png and saved to ./pcb3/normal_png/
# Converted 0240.JPG to 0240.png and saved to ./pcb3/normal_png/
# Converted 0241.JPG to 0241.png and saved to ./pcb3/normal_png/
# Converted 0242.JPG to 0242.png and saved to ./pcb3/normal_png/
# Converted 0243.JPG to 0243.png and saved to ./pcb3/normal_png/
# Converted 0244.JPG to 0244.png and saved to ./pcb3/normal_png/
# Converted 0245.JPG to 0245.png and saved to ./pcb3/normal_png/
# Converted 0246.JPG to 0246.png and saved to ./pcb3/normal_png/
# Converted 0247.JPG to 0247.png and saved to ./pcb3/normal_png/
# Converted 0248.JPG to 0248.png and saved to ./pcb3/normal_png/
# Converted 0249.JPG to 0249.png and saved to ./pcb3/normal_png/
# Converted 0250.JPG to 0250.png and saved to ./pcb3/normal_png/
# Converted 0251.JPG to 0251.png and saved to ./pcb3/normal_png/
# Converted 0252.JPG to 0252.png and saved to ./pcb3/normal_png/
# Converted 0253.JPG to 0253.png and saved to ./pcb3/normal_png/
# Converted 0254.JPG to 0254.png and saved to ./pcb3/normal_png/
# Converted 0255.JPG to 0255.png and saved to ./pcb3/normal_png/
# Converted 0256.JPG to 0256.png and saved to ./pcb3/normal_png/
# Converted 0257.JPG to 0257.png and saved to ./pcb3/normal_png/
# Converted 0258.JPG to 0258.png and saved to ./pcb3/normal_png/
# Converted 0259.JPG to 0259.png and saved to ./pcb3/normal_png/
# Converted 0260.JPG to 0260.png and saved to ./pcb3/normal_png/
# Converted 0261.JPG to 0261.png and saved to ./pcb3/normal_png/
# Converted 0262.JPG to 0262.png and saved to ./pcb3/normal_png/
# Converted 0263.JPG to 0263.png and saved to ./pcb3/normal_png/
# Converted 0264.JPG to 0264.png and saved to ./pcb3/normal_png/
# Converted 0265.JPG to 0265.png and saved to ./pcb3/normal_png/
# Converted 0266.JPG to 0266.png and saved to ./pcb3/normal_png/
# Converted 0267.JPG to 0267.png and saved to ./pcb3/normal_png/
# Converted 0268.JPG to 0268.png and saved to ./pcb3/normal_png/
# Converted 0269.JPG to 0269.png and saved to ./pcb3/normal_png/
# Converted 0270.JPG to 0270.png and saved to ./pcb3/normal_png/
# Converted 0271.JPG to 0271.png and saved to ./pcb3/normal_png/
# Converted 0272.JPG to 0272.png and saved to ./pcb3/normal_png/
# Converted 0273.JPG to 0273.png and saved to ./pcb3/normal_png/
# Converted 0274.JPG to 0274.png and saved to ./pcb3/normal_png/
# Converted 0275.JPG to 0275.png and saved to ./pcb3/normal_png/
# Converted 0276.JPG to 0276.png and saved to ./pcb3/normal_png/
# Converted 0277.JPG to 0277.png and saved to ./pcb3/normal_png/
# Converted 0278.JPG to 0278.png and saved to ./pcb3/normal_png/
# Converted 0279.JPG to 0279.png and saved to ./pcb3/normal_png/
# Converted 0280.JPG to 0280.png and saved to ./pcb3/normal_png/
# Converted 0281.JPG to 0281.png and saved to ./pcb3/normal_png/
# Converted 0282.JPG to 0282.png and saved to ./pcb3/normal_png/
# Converted 0283.JPG to 0283.png and saved to ./pcb3/normal_png/
# Converted 0284.JPG to 0284.png and saved to ./pcb3/normal_png/
# Converted 0285.JPG to 0285.png and saved to ./pcb3/normal_png/
# Converted 0286.JPG to 0286.png and saved to ./pcb3/normal_png/
# Converted 0287.JPG to 0287.png and saved to ./pcb3/normal_png/
# Converted 0288.JPG to 0288.png and saved to ./pcb3/normal_png/
# Converted 0289.JPG to 0289.png and saved to ./pcb3/normal_png/
# Converted 0290.JPG to 0290.png and saved to ./pcb3/normal_png/
# Converted 0291.JPG to 0291.png and saved to ./pcb3/normal_png/
# Converted 0292.JPG to 0292.png and saved to ./pcb3/normal_png/
# Converted 0293.JPG to 0293.png and saved to ./pcb3/normal_png/
# Converted 0294.JPG to 0294.png and saved to ./pcb3/normal_png/
# Converted 0295.JPG to 0295.png and saved to ./pcb3/normal_png/
# Converted 0296.JPG to 0296.png and saved to ./pcb3/normal_png/
# Converted 0297.JPG to 0297.png and saved to ./pcb3/normal_png/
# Converted 0298.JPG to 0298.png and saved to ./pcb3/normal_png/
# Converted 0299.JPG to 0299.png and saved to ./pcb3/normal_png/
# Converted 0300.JPG to 0300.png and saved to ./pcb3/normal_png/
# Converted 0301.JPG to 0301.png and saved to ./pcb3/normal_png/
# Converted 0302.JPG to 0302.png and saved to ./pcb3/normal_png/
# Converted 0303.JPG to 0303.png and saved to ./pcb3/normal_png/
# Converted 0304.JPG to 0304.png and saved to ./pcb3/normal_png/
# Converted 0305.JPG to 0305.png and saved to ./pcb3/normal_png/
# Converted 0306.JPG to 0306.png and saved to ./pcb3/normal_png/
# Converted 0307.JPG to 0307.png and saved to ./pcb3/normal_png/
# Converted 0308.JPG to 0308.png and saved to ./pcb3/normal_png/
# Converted 0309.JPG to 0309.png and saved to ./pcb3/normal_png/
# Converted 0310.JPG to 0310.png and saved to ./pcb3/normal_png/
# Converted 0311.JPG to 0311.png and saved to ./pcb3/normal_png/
# Converted 0312.JPG to 0312.png and saved to ./pcb3/normal_png/
# Converted 0313.JPG to 0313.png and saved to ./pcb3/normal_png/
# Converted 0314.JPG to 0314.png and saved to ./pcb3/normal_png/
# Converted 0315.JPG to 0315.png and saved to ./pcb3/normal_png/
# Converted 0316.JPG to 0316.png and saved to ./pcb3/normal_png/
# Converted 0317.JPG to 0317.png and saved to ./pcb3/normal_png/
# Converted 0318.JPG to 0318.png and saved to ./pcb3/normal_png/
# Converted 0319.JPG to 0319.png and saved to ./pcb3/normal_png/
# Converted 0320.JPG to 0320.png and saved to ./pcb3/normal_png/
# Converted 0321.JPG to 0321.png and saved to ./pcb3/normal_png/
# Converted 0322.JPG to 0322.png and saved to ./pcb3/normal_png/
# Converted 0323.JPG to 0323.png and saved to ./pcb3/normal_png/
# Converted 0324.JPG to 0324.png and saved to ./pcb3/normal_png/
# Converted 0325.JPG to 0325.png and saved to ./pcb3/normal_png/
# Converted 0326.JPG to 0326.png and saved to ./pcb3/normal_png/
# Converted 0327.JPG to 0327.png and saved to ./pcb3/normal_png/
# Converted 0328.JPG to 0328.png and saved to ./pcb3/normal_png/
# Converted 0329.JPG to 0329.png and saved to ./pcb3/normal_png/
# Converted 0330.JPG to 0330.png and saved to ./pcb3/normal_png/
# Converted 0331.JPG to 0331.png and saved to ./pcb3/normal_png/
# Converted 0332.JPG to 0332.png and saved to ./pcb3/normal_png/
# Converted 0333.JPG to 0333.png and saved to ./pcb3/normal_png/
# Converted 0334.JPG to 0334.png and saved to ./pcb3/normal_png/
# Converted 0335.JPG to 0335.png and saved to ./pcb3/normal_png/
# Converted 0336.JPG to 0336.png and saved to ./pcb3/normal_png/
# Converted 0337.JPG to 0337.png and saved to ./pcb3/normal_png/
# Converted 0338.JPG to 0338.png and saved to ./pcb3/normal_png/
# Converted 0339.JPG to 0339.png and saved to ./pcb3/normal_png/
# Converted 0340.JPG to 0340.png and saved to ./pcb3/normal_png/
# Converted 0341.JPG to 0341.png and saved to ./pcb3/normal_png/
# Converted 0342.JPG to 0342.png and saved to ./pcb3/normal_png/
# Converted 0343.JPG to 0343.png and saved to ./pcb3/normal_png/
# Converted 0344.JPG to 0344.png and saved to ./pcb3/normal_png/
# Converted 0345.JPG to 0345.png and saved to ./pcb3/normal_png/
# Converted 0346.JPG to 0346.png and saved to ./pcb3/normal_png/
# Converted 0347.JPG to 0347.png and saved to ./pcb3/normal_png/
# Converted 0348.JPG to 0348.png and saved to ./pcb3/normal_png/
# Converted 0349.JPG to 0349.png and saved to ./pcb3/normal_png/
# Converted 0350.JPG to 0350.png and saved to ./pcb3/normal_png/
# Converted 0351.JPG to 0351.png and saved to ./pcb3/normal_png/
# Converted 0352.JPG to 0352.png and saved to ./pcb3/normal_png/
# Converted 0353.JPG to 0353.png and saved to ./pcb3/normal_png/
# Converted 0354.JPG to 0354.png and saved to ./pcb3/normal_png/
# Converted 0355.JPG to 0355.png and saved to ./pcb3/normal_png/
# Converted 0356.JPG to 0356.png and saved to ./pcb3/normal_png/
# Converted 0357.JPG to 0357.png and saved to ./pcb3/normal_png/
# Converted 0358.JPG to 0358.png and saved to ./pcb3/normal_png/
# Converted 0359.JPG to 0359.png and saved to ./pcb3/normal_png/
# Converted 0360.JPG to 0360.png and saved to ./pcb3/normal_png/
# Converted 0361.JPG to 0361.png and saved to ./pcb3/normal_png/
# Converted 0362.JPG to 0362.png and saved to ./pcb3/normal_png/
# Converted 0363.JPG to 0363.png and saved to ./pcb3/normal_png/
# Converted 0364.JPG to 0364.png and saved to ./pcb3/normal_png/
# Converted 0365.JPG to 0365.png and saved to ./pcb3/normal_png/
# Converted 0366.JPG to 0366.png and saved to ./pcb3/normal_png/
# Converted 0367.JPG to 0367.png and saved to ./pcb3/normal_png/
# Converted 0368.JPG to 0368.png and saved to ./pcb3/normal_png/
# Converted 0369.JPG to 0369.png and saved to ./pcb3/normal_png/
# Converted 0370.JPG to 0370.png and saved to ./pcb3/normal_png/
# Converted 0371.JPG to 0371.png and saved to ./pcb3/normal_png/
# Converted 0372.JPG to 0372.png and saved to ./pcb3/normal_png/
# Converted 0373.JPG to 0373.png and saved to ./pcb3/normal_png/
# Converted 0374.JPG to 0374.png and saved to ./pcb3/normal_png/
# Converted 0375.JPG to 0375.png and saved to ./pcb3/normal_png/
# Converted 0376.JPG to 0376.png and saved to ./pcb3/normal_png/
# Converted 0377.JPG to 0377.png and saved to ./pcb3/normal_png/
# Converted 0378.JPG to 0378.png and saved to ./pcb3/normal_png/
# Converted 0379.JPG to 0379.png and saved to ./pcb3/normal_png/
# Converted 0380.JPG to 0380.png and saved to ./pcb3/normal_png/
# Converted 0381.JPG to 0381.png and saved to ./pcb3/normal_png/
# Converted 0382.JPG to 0382.png and saved to ./pcb3/normal_png/
# Converted 0383.JPG to 0383.png and saved to ./pcb3/normal_png/
# Converted 0384.JPG to 0384.png and saved to ./pcb3/normal_png/
# Converted 0385.JPG to 0385.png and saved to ./pcb3/normal_png/
# Converted 0386.JPG to 0386.png and saved to ./pcb3/normal_png/
# Converted 0387.JPG to 0387.png and saved to ./pcb3/normal_png/
# Converted 0388.JPG to 0388.png and saved to ./pcb3/normal_png/
# Converted 0389.JPG to 0389.png and saved to ./pcb3/normal_png/
# Converted 0390.JPG to 0390.png and saved to ./pcb3/normal_png/
# Converted 0391.JPG to 0391.png and saved to ./pcb3/normal_png/
# Converted 0392.JPG to 0392.png and saved to ./pcb3/normal_png/
# Converted 0393.JPG to 0393.png and saved to ./pcb3/normal_png/
# Converted 0394.JPG to 0394.png and saved to ./pcb3/normal_png/
# Converted 0395.JPG to 0395.png and saved to ./pcb3/normal_png/
# Converted 0396.JPG to 0396.png and saved to ./pcb3/normal_png/
# Converted 0397.JPG to 0397.png and saved to ./pcb3/normal_png/
# Converted 0398.JPG to 0398.png and saved to ./pcb3/normal_png/
# Converted 0399.JPG to 0399.png and saved to ./pcb3/normal_png/
# Converted 0400.JPG to 0400.png and saved to ./pcb3/normal_png/
# Converted 0401.JPG to 0401.png and saved to ./pcb3/normal_png/
# Converted 0402.JPG to 0402.png and saved to ./pcb3/normal_png/
# Converted 0403.JPG to 0403.png and saved to ./pcb3/normal_png/
# Converted 0404.JPG to 0404.png and saved to ./pcb3/normal_png/
# Converted 0405.JPG to 0405.png and saved to ./pcb3/normal_png/
# Converted 0406.JPG to 0406.png and saved to ./pcb3/normal_png/
# Converted 0407.JPG to 0407.png and saved to ./pcb3/normal_png/
# Converted 0408.JPG to 0408.png and saved to ./pcb3/normal_png/
# Converted 0409.JPG to 0409.png and saved to ./pcb3/normal_png/
# Converted 0410.JPG to 0410.png and saved to ./pcb3/normal_png/
# Converted 0411.JPG to 0411.png and saved to ./pcb3/normal_png/
# Converted 0412.JPG to 0412.png and saved to ./pcb3/normal_png/
# Converted 0413.JPG to 0413.png and saved to ./pcb3/normal_png/
# Converted 0414.JPG to 0414.png and saved to ./pcb3/normal_png/
# Converted 0415.JPG to 0415.png and saved to ./pcb3/normal_png/
# Converted 0416.JPG to 0416.png and saved to ./pcb3/normal_png/
# Converted 0417.JPG to 0417.png and saved to ./pcb3/normal_png/
# Converted 0418.JPG to 0418.png and saved to ./pcb3/normal_png/
# Converted 0419.JPG to 0419.png and saved to ./pcb3/normal_png/
# Converted 0420.JPG to 0420.png and saved to ./pcb3/normal_png/
# Converted 0421.JPG to 0421.png and saved to ./pcb3/normal_png/
# Converted 0422.JPG to 0422.png and saved to ./pcb3/normal_png/
# Converted 0423.JPG to 0423.png and saved to ./pcb3/normal_png/
# Converted 0424.JPG to 0424.png and saved to ./pcb3/normal_png/
# Converted 0425.JPG to 0425.png and saved to ./pcb3/normal_png/
# Converted 0426.JPG to 0426.png and saved to ./pcb3/normal_png/
# Converted 0427.JPG to 0427.png and saved to ./pcb3/normal_png/
# Converted 0428.JPG to 0428.png and saved to ./pcb3/normal_png/
# Converted 0429.JPG to 0429.png and saved to ./pcb3/normal_png/
# Converted 0430.JPG to 0430.png and saved to ./pcb3/normal_png/
# Converted 0431.JPG to 0431.png and saved to ./pcb3/normal_png/
# Converted 0432.JPG to 0432.png and saved to ./pcb3/normal_png/
# Converted 0433.JPG to 0433.png and saved to ./pcb3/normal_png/
# Converted 0434.JPG to 0434.png and saved to ./pcb3/normal_png/
# Converted 0435.JPG to 0435.png and saved to ./pcb3/normal_png/
# Converted 0436.JPG to 0436.png and saved to ./pcb3/normal_png/
# Converted 0437.JPG to 0437.png and saved to ./pcb3/normal_png/
# Converted 0438.JPG to 0438.png and saved to ./pcb3/normal_png/
# Converted 0439.JPG to 0439.png and saved to ./pcb3/normal_png/
# Converted 0440.JPG to 0440.png and saved to ./pcb3/normal_png/
# Converted 0441.JPG to 0441.png and saved to ./pcb3/normal_png/
# Converted 0442.JPG to 0442.png and saved to ./pcb3/normal_png/
# Converted 0443.JPG to 0443.png and saved to ./pcb3/normal_png/
# Converted 0444.JPG to 0444.png and saved to ./pcb3/normal_png/
# Converted 0445.JPG to 0445.png and saved to ./pcb3/normal_png/
# Converted 0446.JPG to 0446.png and saved to ./pcb3/normal_png/
# Converted 0447.JPG to 0447.png and saved to ./pcb3/normal_png/
# Converted 0448.JPG to 0448.png and saved to ./pcb3/normal_png/
# Converted 0449.JPG to 0449.png and saved to ./pcb3/normal_png/
# Converted 0450.JPG to 0450.png and saved to ./pcb3/normal_png/
# Converted 0451.JPG to 0451.png and saved to ./pcb3/normal_png/
# Converted 0452.JPG to 0452.png and saved to ./pcb3/normal_png/
# Converted 0453.JPG to 0453.png and saved to ./pcb3/normal_png/
# Converted 0454.JPG to 0454.png and saved to ./pcb3/normal_png/
# Converted 0455.JPG to 0455.png and saved to ./pcb3/normal_png/
# Converted 0456.JPG to 0456.png and saved to ./pcb3/normal_png/
# Converted 0457.JPG to 0457.png and saved to ./pcb3/normal_png/
# Converted 0458.JPG to 0458.png and saved to ./pcb3/normal_png/
# Converted 0459.JPG to 0459.png and saved to ./pcb3/normal_png/
# Converted 0460.JPG to 0460.png and saved to ./pcb3/normal_png/
# Converted 0461.JPG to 0461.png and saved to ./pcb3/normal_png/
# Converted 0462.JPG to 0462.png and saved to ./pcb3/normal_png/
# Converted 0463.JPG to 0463.png and saved to ./pcb3/normal_png/
# Converted 0464.JPG to 0464.png and saved to ./pcb3/normal_png/
# Converted 0465.JPG to 0465.png and saved to ./pcb3/normal_png/
# Converted 0466.JPG to 0466.png and saved to ./pcb3/normal_png/
# Converted 0467.JPG to 0467.png and saved to ./pcb3/normal_png/
# Converted 0468.JPG to 0468.png and saved to ./pcb3/normal_png/
# Converted 0469.JPG to 0469.png and saved to ./pcb3/normal_png/
# Converted 0470.JPG to 0470.png and saved to ./pcb3/normal_png/
# Converted 0471.JPG to 0471.png and saved to ./pcb3/normal_png/
# Converted 0472.JPG to 0472.png and saved to ./pcb3/normal_png/
# Converted 0473.JPG to 0473.png and saved to ./pcb3/normal_png/
# Converted 0474.JPG to 0474.png and saved to ./pcb3/normal_png/
# Converted 0475.JPG to 0475.png and saved to ./pcb3/normal_png/
# Converted 0476.JPG to 0476.png and saved to ./pcb3/normal_png/
# Converted 0477.JPG to 0477.png and saved to ./pcb3/normal_png/
# Converted 0478.JPG to 0478.png and saved to ./pcb3/normal_png/
# Converted 0479.JPG to 0479.png and saved to ./pcb3/normal_png/
# Converted 0480.JPG to 0480.png and saved to ./pcb3/normal_png/
# Converted 0481.JPG to 0481.png and saved to ./pcb3/normal_png/
# Converted 0482.JPG to 0482.png and saved to ./pcb3/normal_png/
# Converted 0483.JPG to 0483.png and saved to ./pcb3/normal_png/
# Converted 0484.JPG to 0484.png and saved to ./pcb3/normal_png/
# Converted 0485.JPG to 0485.png and saved to ./pcb3/normal_png/
# Converted 0486.JPG to 0486.png and saved to ./pcb3/normal_png/
# Converted 0487.JPG to 0487.png and saved to ./pcb3/normal_png/
# Converted 0488.JPG to 0488.png and saved to ./pcb3/normal_png/
# Converted 0489.JPG to 0489.png and saved to ./pcb3/normal_png/
# Converted 0490.JPG to 0490.png and saved to ./pcb3/normal_png/
# Converted 0491.JPG to 0491.png and saved to ./pcb3/normal_png/
# Converted 0492.JPG to 0492.png and saved to ./pcb3/normal_png/
# Converted 0493.JPG to 0493.png and saved to ./pcb3/normal_png/
# Converted 0494.JPG to 0494.png and saved to ./pcb3/normal_png/
# Converted 0495.JPG to 0495.png and saved to ./pcb3/normal_png/
# Converted 0496.JPG to 0496.png and saved to ./pcb3/normal_png/
# Converted 0497.JPG to 0497.png and saved to ./pcb3/normal_png/
# Converted 0498.JPG to 0498.png and saved to ./pcb3/normal_png/
# Converted 0499.JPG to 0499.png and saved to ./pcb3/normal_png/
# Converted 0500.JPG to 0500.png and saved to ./pcb3/normal_png/
# Converted 0501.JPG to 0501.png and saved to ./pcb3/normal_png/
# Converted 0502.JPG to 0502.png and saved to ./pcb3/normal_png/
# Converted 0503.JPG to 0503.png and saved to ./pcb3/normal_png/
# Converted 0504.JPG to 0504.png and saved to ./pcb3/normal_png/
# Converted 0505.JPG to 0505.png and saved to ./pcb3/normal_png/
# Converted 0506.JPG to 0506.png and saved to ./pcb3/normal_png/
# Converted 0507.JPG to 0507.png and saved to ./pcb3/normal_png/
# Converted 0508.JPG to 0508.png and saved to ./pcb3/normal_png/
# Converted 0509.JPG to 0509.png and saved to ./pcb3/normal_png/
# Converted 0510.JPG to 0510.png and saved to ./pcb3/normal_png/
# Converted 0511.JPG to 0511.png and saved to ./pcb3/normal_png/
# Converted 0512.JPG to 0512.png and saved to ./pcb3/normal_png/
# Converted 0513.JPG to 0513.png and saved to ./pcb3/normal_png/
# Converted 0514.JPG to 0514.png and saved to ./pcb3/normal_png/
# Converted 0515.JPG to 0515.png and saved to ./pcb3/normal_png/
# Converted 0516.JPG to 0516.png and saved to ./pcb3/normal_png/
# Converted 0517.JPG to 0517.png and saved to ./pcb3/normal_png/
# Converted 0518.JPG to 0518.png and saved to ./pcb3/normal_png/
# Converted 0519.JPG to 0519.png and saved to ./pcb3/normal_png/
# Converted 0520.JPG to 0520.png and saved to ./pcb3/normal_png/
# Converted 0521.JPG to 0521.png and saved to ./pcb3/normal_png/
# Converted 0522.JPG to 0522.png and saved to ./pcb3/normal_png/
# Converted 0523.JPG to 0523.png and saved to ./pcb3/normal_png/
# Converted 0524.JPG to 0524.png and saved to ./pcb3/normal_png/
# Converted 0525.JPG to 0525.png and saved to ./pcb3/normal_png/
# Converted 0526.JPG to 0526.png and saved to ./pcb3/normal_png/
# Converted 0527.JPG to 0527.png and saved to ./pcb3/normal_png/
# Converted 0528.JPG to 0528.png and saved to ./pcb3/normal_png/
# Converted 0529.JPG to 0529.png and saved to ./pcb3/normal_png/
# Converted 0530.JPG to 0530.png and saved to ./pcb3/normal_png/
# Converted 0531.JPG to 0531.png and saved to ./pcb3/normal_png/
# Converted 0532.JPG to 0532.png and saved to ./pcb3/normal_png/
# Converted 0533.JPG to 0533.png and saved to ./pcb3/normal_png/
# Converted 0534.JPG to 0534.png and saved to ./pcb3/normal_png/
# Converted 0535.JPG to 0535.png and saved to ./pcb3/normal_png/
# Converted 0536.JPG to 0536.png and saved to ./pcb3/normal_png/
# Converted 0537.JPG to 0537.png and saved to ./pcb3/normal_png/
# Converted 0538.JPG to 0538.png and saved to ./pcb3/normal_png/
# Converted 0539.JPG to 0539.png and saved to ./pcb3/normal_png/
# Converted 0540.JPG to 0540.png and saved to ./pcb3/normal_png/
# Converted 0541.JPG to 0541.png and saved to ./pcb3/normal_png/
# Converted 0542.JPG to 0542.png and saved to ./pcb3/normal_png/
# Converted 0543.JPG to 0543.png and saved to ./pcb3/normal_png/
# Converted 0544.JPG to 0544.png and saved to ./pcb3/normal_png/
# Converted 0545.JPG to 0545.png and saved to ./pcb3/normal_png/
# Converted 0546.JPG to 0546.png and saved to ./pcb3/normal_png/
# Converted 0547.JPG to 0547.png and saved to ./pcb3/normal_png/
# Converted 0548.JPG to 0548.png and saved to ./pcb3/normal_png/
# Converted 0549.JPG to 0549.png and saved to ./pcb3/normal_png/
# Converted 0550.JPG to 0550.png and saved to ./pcb3/normal_png/
# Converted 0551.JPG to 0551.png and saved to ./pcb3/normal_png/
# Converted 0552.JPG to 0552.png and saved to ./pcb3/normal_png/
# Converted 0553.JPG to 0553.png and saved to ./pcb3/normal_png/
# Converted 0554.JPG to 0554.png and saved to ./pcb3/normal_png/
# Converted 0555.JPG to 0555.png and saved to ./pcb3/normal_png/
# Converted 0556.JPG to 0556.png and saved to ./pcb3/normal_png/
# Converted 0557.JPG to 0557.png and saved to ./pcb3/normal_png/
# Converted 0558.JPG to 0558.png and saved to ./pcb3/normal_png/
# Converted 0559.JPG to 0559.png and saved to ./pcb3/normal_png/
# Converted 0560.JPG to 0560.png and saved to ./pcb3/normal_png/
# Converted 0561.JPG to 0561.png and saved to ./pcb3/normal_png/
# Converted 0562.JPG to 0562.png and saved to ./pcb3/normal_png/
# Converted 0563.JPG to 0563.png and saved to ./pcb3/normal_png/
# Converted 0564.JPG to 0564.png and saved to ./pcb3/normal_png/
# Converted 0565.JPG to 0565.png and saved to ./pcb3/normal_png/
# Converted 0566.JPG to 0566.png and saved to ./pcb3/normal_png/
# Converted 0567.JPG to 0567.png and saved to ./pcb3/normal_png/
# Converted 0568.JPG to 0568.png and saved to ./pcb3/normal_png/
# Converted 0569.JPG to 0569.png and saved to ./pcb3/normal_png/
# Converted 0570.JPG to 0570.png and saved to ./pcb3/normal_png/
# Converted 0571.JPG to 0571.png and saved to ./pcb3/normal_png/
# Converted 0572.JPG to 0572.png and saved to ./pcb3/normal_png/
# Converted 0573.JPG to 0573.png and saved to ./pcb3/normal_png/
# Converted 0574.JPG to 0574.png and saved to ./pcb3/normal_png/
# Converted 0575.JPG to 0575.png and saved to ./pcb3/normal_png/
# Converted 0576.JPG to 0576.png and saved to ./pcb3/normal_png/
# Converted 0577.JPG to 0577.png and saved to ./pcb3/normal_png/
# Converted 0578.JPG to 0578.png and saved to ./pcb3/normal_png/
# Converted 0579.JPG to 0579.png and saved to ./pcb3/normal_png/
# Converted 0580.JPG to 0580.png and saved to ./pcb3/normal_png/
# Converted 0581.JPG to 0581.png and saved to ./pcb3/normal_png/
# Converted 0582.JPG to 0582.png and saved to ./pcb3/normal_png/
# Converted 0583.JPG to 0583.png and saved to ./pcb3/normal_png/
# Converted 0584.JPG to 0584.png and saved to ./pcb3/normal_png/
# Converted 0585.JPG to 0585.png and saved to ./pcb3/normal_png/
# Converted 0586.JPG to 0586.png and saved to ./pcb3/normal_png/
# Converted 0587.JPG to 0587.png and saved to ./pcb3/normal_png/
# Converted 0588.JPG to 0588.png and saved to ./pcb3/normal_png/
# Converted 0589.JPG to 0589.png and saved to ./pcb3/normal_png/
# Converted 0590.JPG to 0590.png and saved to ./pcb3/normal_png/
# Converted 0591.JPG to 0591.png and saved to ./pcb3/normal_png/
# Converted 0592.JPG to 0592.png and saved to ./pcb3/normal_png/
# Converted 0593.JPG to 0593.png and saved to ./pcb3/normal_png/
# Converted 0594.JPG to 0594.png and saved to ./pcb3/normal_png/
# Converted 0595.JPG to 0595.png and saved to ./pcb3/normal_png/
# Converted 0596.JPG to 0596.png and saved to ./pcb3/normal_png/
# Converted 0597.JPG to 0597.png and saved to ./pcb3/normal_png/
# Converted 0598.JPG to 0598.png and saved to ./pcb3/normal_png/
# Converted 0599.JPG to 0599.png and saved to ./pcb3/normal_png/
# Converted 0600.JPG to 0600.png and saved to ./pcb3/normal_png/
# Converted 0601.JPG to 0601.png and saved to ./pcb3/normal_png/
# Converted 0602.JPG to 0602.png and saved to ./pcb3/normal_png/
# Converted 0603.JPG to 0603.png and saved to ./pcb3/normal_png/
# Converted 0604.JPG to 0604.png and saved to ./pcb3/normal_png/
# Converted 0605.JPG to 0605.png and saved to ./pcb3/normal_png/
# Converted 0606.JPG to 0606.png and saved to ./pcb3/normal_png/
# Converted 0607.JPG to 0607.png and saved to ./pcb3/normal_png/
# Converted 0608.JPG to 0608.png and saved to ./pcb3/normal_png/
# Converted 0609.JPG to 0609.png and saved to ./pcb3/normal_png/
# Converted 0610.JPG to 0610.png and saved to ./pcb3/normal_png/
# Converted 0611.JPG to 0611.png and saved to ./pcb3/normal_png/
# Converted 0612.JPG to 0612.png and saved to ./pcb3/normal_png/
# Converted 0613.JPG to 0613.png and saved to ./pcb3/normal_png/
# Converted 0614.JPG to 0614.png and saved to ./pcb3/normal_png/
# Converted 0615.JPG to 0615.png and saved to ./pcb3/normal_png/
# Converted 0616.JPG to 0616.png and saved to ./pcb3/normal_png/
# Converted 0617.JPG to 0617.png and saved to ./pcb3/normal_png/
# Converted 0618.JPG to 0618.png and saved to ./pcb3/normal_png/
# Converted 0619.JPG to 0619.png and saved to ./pcb3/normal_png/
# Converted 0620.JPG to 0620.png and saved to ./pcb3/normal_png/
# Converted 0621.JPG to 0621.png and saved to ./pcb3/normal_png/
# Converted 0622.JPG to 0622.png and saved to ./pcb3/normal_png/
# Converted 0623.JPG to 0623.png and saved to ./pcb3/normal_png/
# Converted 0624.JPG to 0624.png and saved to ./pcb3/normal_png/
# Converted 0625.JPG to 0625.png and saved to ./pcb3/normal_png/
# Converted 0626.JPG to 0626.png and saved to ./pcb3/normal_png/
# Converted 0627.JPG to 0627.png and saved to ./pcb3/normal_png/
# Converted 0628.JPG to 0628.png and saved to ./pcb3/normal_png/
# Converted 0629.JPG to 0629.png and saved to ./pcb3/normal_png/
# Converted 0630.JPG to 0630.png and saved to ./pcb3/normal_png/
# Converted 0631.JPG to 0631.png and saved to ./pcb3/normal_png/
# Converted 0632.JPG to 0632.png and saved to ./pcb3/normal_png/
# Converted 0633.JPG to 0633.png and saved to ./pcb3/normal_png/
# Converted 0634.JPG to 0634.png and saved to ./pcb3/normal_png/
# Converted 0635.JPG to 0635.png and saved to ./pcb3/normal_png/
# Converted 0636.JPG to 0636.png and saved to ./pcb3/normal_png/
# Converted 0637.JPG to 0637.png and saved to ./pcb3/normal_png/
# Converted 0638.JPG to 0638.png and saved to ./pcb3/normal_png/
# Converted 0639.JPG to 0639.png and saved to ./pcb3/normal_png/
# Converted 0640.JPG to 0640.png and saved to ./pcb3/normal_png/
# Converted 0641.JPG to 0641.png and saved to ./pcb3/normal_png/
# Converted 0642.JPG to 0642.png and saved to ./pcb3/normal_png/
# Converted 0643.JPG to 0643.png and saved to ./pcb3/normal_png/
# Converted 0644.JPG to 0644.png and saved to ./pcb3/normal_png/
# Converted 0645.JPG to 0645.png and saved to ./pcb3/normal_png/
# Converted 0646.JPG to 0646.png and saved to ./pcb3/normal_png/
# Converted 0647.JPG to 0647.png and saved to ./pcb3/normal_png/
# Converted 0648.JPG to 0648.png and saved to ./pcb3/normal_png/
# Converted 0649.JPG to 0649.png and saved to ./pcb3/normal_png/
# Converted 0650.JPG to 0650.png and saved to ./pcb3/normal_png/
# Converted 0651.JPG to 0651.png and saved to ./pcb3/normal_png/
# Converted 0652.JPG to 0652.png and saved to ./pcb3/normal_png/
# Converted 0653.JPG to 0653.png and saved to ./pcb3/normal_png/
# Converted 0654.JPG to 0654.png and saved to ./pcb3/normal_png/
# Converted 0655.JPG to 0655.png and saved to ./pcb3/normal_png/
# Converted 0656.JPG to 0656.png and saved to ./pcb3/normal_png/
# Converted 0657.JPG to 0657.png and saved to ./pcb3/normal_png/
# Converted 0658.JPG to 0658.png and saved to ./pcb3/normal_png/
# Converted 0659.JPG to 0659.png and saved to ./pcb3/normal_png/
# Converted 0660.JPG to 0660.png and saved to ./pcb3/normal_png/
# Converted 0661.JPG to 0661.png and saved to ./pcb3/normal_png/
# Converted 0662.JPG to 0662.png and saved to ./pcb3/normal_png/
# Converted 0663.JPG to 0663.png and saved to ./pcb3/normal_png/
# Converted 0664.JPG to 0664.png and saved to ./pcb3/normal_png/
# Converted 0665.JPG to 0665.png and saved to ./pcb3/normal_png/
# Converted 0666.JPG to 0666.png and saved to ./pcb3/normal_png/
# Converted 0667.JPG to 0667.png and saved to ./pcb3/normal_png/
# Converted 0668.JPG to 0668.png and saved to ./pcb3/normal_png/
# Converted 0669.JPG to 0669.png and saved to ./pcb3/normal_png/
# Converted 0670.JPG to 0670.png and saved to ./pcb3/normal_png/
# Converted 0671.JPG to 0671.png and saved to ./pcb3/normal_png/
# Converted 0672.JPG to 0672.png and saved to ./pcb3/normal_png/
# Converted 0673.JPG to 0673.png and saved to ./pcb3/normal_png/
# Converted 0674.JPG to 0674.png and saved to ./pcb3/normal_png/
# Converted 0675.JPG to 0675.png and saved to ./pcb3/normal_png/
# Converted 0676.JPG to 0676.png and saved to ./pcb3/normal_png/
# Converted 0677.JPG to 0677.png and saved to ./pcb3/normal_png/
# Converted 0678.JPG to 0678.png and saved to ./pcb3/normal_png/
# Converted 0679.JPG to 0679.png and saved to ./pcb3/normal_png/
# Converted 0680.JPG to 0680.png and saved to ./pcb3/normal_png/
# Converted 0681.JPG to 0681.png and saved to ./pcb3/normal_png/
# Converted 0682.JPG to 0682.png and saved to ./pcb3/normal_png/
# Converted 0683.JPG to 0683.png and saved to ./pcb3/normal_png/
# Converted 0684.JPG to 0684.png and saved to ./pcb3/normal_png/
# Converted 0685.JPG to 0685.png and saved to ./pcb3/normal_png/
# Converted 0686.JPG to 0686.png and saved to ./pcb3/normal_png/
# Converted 0687.JPG to 0687.png and saved to ./pcb3/normal_png/
# Converted 0688.JPG to 0688.png and saved to ./pcb3/normal_png/
# Converted 0689.JPG to 0689.png and saved to ./pcb3/normal_png/
# Converted 0690.JPG to 0690.png and saved to ./pcb3/normal_png/
# Converted 0691.JPG to 0691.png and saved to ./pcb3/normal_png/
# Converted 0692.JPG to 0692.png and saved to ./pcb3/normal_png/
# Converted 0693.JPG to 0693.png and saved to ./pcb3/normal_png/
# Converted 0694.JPG to 0694.png and saved to ./pcb3/normal_png/
# Converted 0695.JPG to 0695.png and saved to ./pcb3/normal_png/
# Converted 0696.JPG to 0696.png and saved to ./pcb3/normal_png/
# Converted 0697.JPG to 0697.png and saved to ./pcb3/normal_png/
# Converted 0698.JPG to 0698.png and saved to ./pcb3/normal_png/
# Converted 0699.JPG to 0699.png and saved to ./pcb3/normal_png/
# Converted 0700.JPG to 0700.png and saved to ./pcb3/normal_png/
# Converted 0701.JPG to 0701.png and saved to ./pcb3/normal_png/
# Converted 0702.JPG to 0702.png and saved to ./pcb3/normal_png/
# Converted 0703.JPG to 0703.png and saved to ./pcb3/normal_png/
# Converted 0704.JPG to 0704.png and saved to ./pcb3/normal_png/
# Converted 0705.JPG to 0705.png and saved to ./pcb3/normal_png/
# Converted 0706.JPG to 0706.png and saved to ./pcb3/normal_png/
# Converted 0707.JPG to 0707.png and saved to ./pcb3/normal_png/
# Converted 0708.JPG to 0708.png and saved to ./pcb3/normal_png/
# Converted 0709.JPG to 0709.png and saved to ./pcb3/normal_png/
# Converted 0710.JPG to 0710.png and saved to ./pcb3/normal_png/
# Converted 0711.JPG to 0711.png and saved to ./pcb3/normal_png/
# Converted 0712.JPG to 0712.png and saved to ./pcb3/normal_png/
# Converted 0713.JPG to 0713.png and saved to ./pcb3/normal_png/
# Converted 0714.JPG to 0714.png and saved to ./pcb3/normal_png/
# Converted 0715.JPG to 0715.png and saved to ./pcb3/normal_png/
# Converted 0716.JPG to 0716.png and saved to ./pcb3/normal_png/
# Converted 0717.JPG to 0717.png and saved to ./pcb3/normal_png/
# Converted 0718.JPG to 0718.png and saved to ./pcb3/normal_png/
# Converted 0719.JPG to 0719.png and saved to ./pcb3/normal_png/
# Converted 0720.JPG to 0720.png and saved to ./pcb3/normal_png/
# Converted 0721.JPG to 0721.png and saved to ./pcb3/normal_png/
# Converted 0722.JPG to 0722.png and saved to ./pcb3/normal_png/
# Converted 0723.JPG to 0723.png and saved to ./pcb3/normal_png/
# Converted 0724.JPG to 0724.png and saved to ./pcb3/normal_png/
# Converted 0725.JPG to 0725.png and saved to ./pcb3/normal_png/
# Converted 0726.JPG to 0726.png and saved to ./pcb3/normal_png/
# Converted 0727.JPG to 0727.png and saved to ./pcb3/normal_png/
# Converted 0728.JPG to 0728.png and saved to ./pcb3/normal_png/
# Converted 0729.JPG to 0729.png and saved to ./pcb3/normal_png/
# Converted 0730.JPG to 0730.png and saved to ./pcb3/normal_png/
# Converted 0731.JPG to 0731.png and saved to ./pcb3/normal_png/
# Converted 0732.JPG to 0732.png and saved to ./pcb3/normal_png/
# Converted 0733.JPG to 0733.png and saved to ./pcb3/normal_png/
# Converted 0734.JPG to 0734.png and saved to ./pcb3/normal_png/
# Converted 0735.JPG to 0735.png and saved to ./pcb3/normal_png/
# Converted 0736.JPG to 0736.png and saved to ./pcb3/normal_png/
# Converted 0737.JPG to 0737.png and saved to ./pcb3/normal_png/
# Converted 0738.JPG to 0738.png and saved to ./pcb3/normal_png/
# Converted 0739.JPG to 0739.png and saved to ./pcb3/normal_png/
# Converted 0740.JPG to 0740.png and saved to ./pcb3/normal_png/
# Converted 0741.JPG to 0741.png and saved to ./pcb3/normal_png/
# Converted 0742.JPG to 0742.png and saved to ./pcb3/normal_png/
# Converted 0743.JPG to 0743.png and saved to ./pcb3/normal_png/
# Converted 0744.JPG to 0744.png and saved to ./pcb3/normal_png/
# Converted 0745.JPG to 0745.png and saved to ./pcb3/normal_png/
# Converted 0746.JPG to 0746.png and saved to ./pcb3/normal_png/
# Converted 0747.JPG to 0747.png and saved to ./pcb3/normal_png/
# Converted 0748.JPG to 0748.png and saved to ./pcb3/normal_png/
# Converted 0749.JPG to 0749.png and saved to ./pcb3/normal_png/
# Converted 0750.JPG to 0750.png and saved to ./pcb3/normal_png/
# Converted 0751.JPG to 0751.png and saved to ./pcb3/normal_png/
# Converted 0752.JPG to 0752.png and saved to ./pcb3/normal_png/
# Converted 0753.JPG to 0753.png and saved to ./pcb3/normal_png/
# Converted 0754.JPG to 0754.png and saved to ./pcb3/normal_png/
# Converted 0755.JPG to 0755.png and saved to ./pcb3/normal_png/
# Converted 0756.JPG to 0756.png and saved to ./pcb3/normal_png/
# Converted 0757.JPG to 0757.png and saved to ./pcb3/normal_png/
# Converted 0758.JPG to 0758.png and saved to ./pcb3/normal_png/
# Converted 0759.JPG to 0759.png and saved to ./pcb3/normal_png/
# Converted 0760.JPG to 0760.png and saved to ./pcb3/normal_png/
# Converted 0761.JPG to 0761.png and saved to ./pcb3/normal_png/
# Converted 0762.JPG to 0762.png and saved to ./pcb3/normal_png/
# Converted 0763.JPG to 0763.png and saved to ./pcb3/normal_png/
# Converted 0764.JPG to 0764.png and saved to ./pcb3/normal_png/
# Converted 0765.JPG to 0765.png and saved to ./pcb3/normal_png/
# Converted 0766.JPG to 0766.png and saved to ./pcb3/normal_png/
# Converted 0767.JPG to 0767.png and saved to ./pcb3/normal_png/
# Converted 0768.JPG to 0768.png and saved to ./pcb3/normal_png/
# Converted 0769.JPG to 0769.png and saved to ./pcb3/normal_png/
# Converted 0770.JPG to 0770.png and saved to ./pcb3/normal_png/
# Converted 0771.JPG to 0771.png and saved to ./pcb3/normal_png/
# Converted 0772.JPG to 0772.png and saved to ./pcb3/normal_png/
# Converted 0773.JPG to 0773.png and saved to ./pcb3/normal_png/
# Converted 0774.JPG to 0774.png and saved to ./pcb3/normal_png/
# Converted 0775.JPG to 0775.png and saved to ./pcb3/normal_png/
# Converted 0776.JPG to 0776.png and saved to ./pcb3/normal_png/
# Converted 0777.JPG to 0777.png and saved to ./pcb3/normal_png/
# Converted 0778.JPG to 0778.png and saved to ./pcb3/normal_png/
# Converted 0779.JPG to 0779.png and saved to ./pcb3/normal_png/
# Converted 0780.JPG to 0780.png and saved to ./pcb3/normal_png/
# Converted 0781.JPG to 0781.png and saved to ./pcb3/normal_png/
# Converted 0782.JPG to 0782.png and saved to ./pcb3/normal_png/
# Converted 0783.JPG to 0783.png and saved to ./pcb3/normal_png/
# Converted 0784.JPG to 0784.png and saved to ./pcb3/normal_png/
# Converted 0785.JPG to 0785.png and saved to ./pcb3/normal_png/
# Converted 0786.JPG to 0786.png and saved to ./pcb3/normal_png/
# Converted 0787.JPG to 0787.png and saved to ./pcb3/normal_png/
# Converted 0788.JPG to 0788.png and saved to ./pcb3/normal_png/
# Converted 0789.JPG to 0789.png and saved to ./pcb3/normal_png/
# Converted 0790.JPG to 0790.png and saved to ./pcb3/normal_png/
# Converted 0791.JPG to 0791.png and saved to ./pcb3/normal_png/
# Converted 0792.JPG to 0792.png and saved to ./pcb3/normal_png/
# Converted 0793.JPG to 0793.png and saved to ./pcb3/normal_png/
# Converted 0794.JPG to 0794.png and saved to ./pcb3/normal_png/
# Converted 0795.JPG to 0795.png and saved to ./pcb3/normal_png/
# Converted 0796.JPG to 0796.png and saved to ./pcb3/normal_png/
# Converted 0797.JPG to 0797.png and saved to ./pcb3/normal_png/
# Converted 0798.JPG to 0798.png and saved to ./pcb3/normal_png/
# Converted 0799.JPG to 0799.png and saved to ./pcb3/normal_png/
# Converted 0800.JPG to 0800.png and saved to ./pcb3/normal_png/
# Converted 0801.JPG to 0801.png and saved to ./pcb3/normal_png/
# Converted 0802.JPG to 0802.png and saved to ./pcb3/normal_png/
# Converted 0803.JPG to 0803.png and saved to ./pcb3/normal_png/
# Converted 0804.JPG to 0804.png and saved to ./pcb3/normal_png/
# Converted 0805.JPG to 0805.png and saved to ./pcb3/normal_png/
# Converted 0806.JPG to 0806.png and saved to ./pcb3/normal_png/
# Converted 0807.JPG to 0807.png and saved to ./pcb3/normal_png/
# Converted 0808.JPG to 0808.png and saved to ./pcb3/normal_png/
# Converted 0809.JPG to 0809.png and saved to ./pcb3/normal_png/
# Converted 0810.JPG to 0810.png and saved to ./pcb3/normal_png/
# Converted 0811.JPG to 0811.png and saved to ./pcb3/normal_png/
# Converted 0812.JPG to 0812.png and saved to ./pcb3/normal_png/
# Converted 0813.JPG to 0813.png and saved to ./pcb3/normal_png/
# Converted 0814.JPG to 0814.png and saved to ./pcb3/normal_png/
# Converted 0815.JPG to 0815.png and saved to ./pcb3/normal_png/
# Converted 0816.JPG to 0816.png and saved to ./pcb3/normal_png/
# Converted 0817.JPG to 0817.png and saved to ./pcb3/normal_png/
# Converted 0818.JPG to 0818.png and saved to ./pcb3/normal_png/
# Converted 0819.JPG to 0819.png and saved to ./pcb3/normal_png/
# Converted 0820.JPG to 0820.png and saved to ./pcb3/normal_png/
# Converted 0821.JPG to 0821.png and saved to ./pcb3/normal_png/
# Converted 0822.JPG to 0822.png and saved to ./pcb3/normal_png/
# Converted 0823.JPG to 0823.png and saved to ./pcb3/normal_png/
# Converted 0824.JPG to 0824.png and saved to ./pcb3/normal_png/
# Converted 0825.JPG to 0825.png and saved to ./pcb3/normal_png/
# Converted 0826.JPG to 0826.png and saved to ./pcb3/normal_png/
# Converted 0827.JPG to 0827.png and saved to ./pcb3/normal_png/
# Converted 0828.JPG to 0828.png and saved to ./pcb3/normal_png/
# Converted 0829.JPG to 0829.png and saved to ./pcb3/normal_png/
# Converted 0830.JPG to 0830.png and saved to ./pcb3/normal_png/
# Converted 0831.JPG to 0831.png and saved to ./pcb3/normal_png/
# Converted 0832.JPG to 0832.png and saved to ./pcb3/normal_png/
# Converted 0833.JPG to 0833.png and saved to ./pcb3/normal_png/
# Converted 0834.JPG to 0834.png and saved to ./pcb3/normal_png/
# Converted 0835.JPG to 0835.png and saved to ./pcb3/normal_png/
# Converted 0836.JPG to 0836.png and saved to ./pcb3/normal_png/
# Converted 0837.JPG to 0837.png and saved to ./pcb3/normal_png/
# Converted 0838.JPG to 0838.png and saved to ./pcb3/normal_png/
# Converted 0839.JPG to 0839.png and saved to ./pcb3/normal_png/
# Converted 0840.JPG to 0840.png and saved to ./pcb3/normal_png/
# Converted 0841.JPG to 0841.png and saved to ./pcb3/normal_png/
# Converted 0842.JPG to 0842.png and saved to ./pcb3/normal_png/
# Converted 0843.JPG to 0843.png and saved to ./pcb3/normal_png/
# Converted 0844.JPG to 0844.png and saved to ./pcb3/normal_png/
# Converted 0845.JPG to 0845.png and saved to ./pcb3/normal_png/
# Converted 0846.JPG to 0846.png and saved to ./pcb3/normal_png/
# Converted 0847.JPG to 0847.png and saved to ./pcb3/normal_png/
# Converted 0848.JPG to 0848.png and saved to ./pcb3/normal_png/
# Converted 0849.JPG to 0849.png and saved to ./pcb3/normal_png/
# Converted 0850.JPG to 0850.png and saved to ./pcb3/normal_png/
# Converted 0851.JPG to 0851.png and saved to ./pcb3/normal_png/
# Converted 0852.JPG to 0852.png and saved to ./pcb3/normal_png/
# Converted 0853.JPG to 0853.png and saved to ./pcb3/normal_png/
# Converted 0854.JPG to 0854.png and saved to ./pcb3/normal_png/
# Converted 0855.JPG to 0855.png and saved to ./pcb3/normal_png/
# Converted 0856.JPG to 0856.png and saved to ./pcb3/normal_png/
# Converted 0857.JPG to 0857.png and saved to ./pcb3/normal_png/
# Converted 0858.JPG to 0858.png and saved to ./pcb3/normal_png/
# Converted 0859.JPG to 0859.png and saved to ./pcb3/normal_png/
# Converted 0860.JPG to 0860.png and saved to ./pcb3/normal_png/
# Converted 0861.JPG to 0861.png and saved to ./pcb3/normal_png/
# Converted 0862.JPG to 0862.png and saved to ./pcb3/normal_png/
# Converted 0863.JPG to 0863.png and saved to ./pcb3/normal_png/
# Converted 0864.JPG to 0864.png and saved to ./pcb3/normal_png/
# Converted 0865.JPG to 0865.png and saved to ./pcb3/normal_png/
# Converted 0866.JPG to 0866.png and saved to ./pcb3/normal_png/
# Converted 0867.JPG to 0867.png and saved to ./pcb3/normal_png/
# Converted 0868.JPG to 0868.png and saved to ./pcb3/normal_png/
# Converted 0869.JPG to 0869.png and saved to ./pcb3/normal_png/
# Converted 0870.JPG to 0870.png and saved to ./pcb3/normal_png/
# Converted 0871.JPG to 0871.png and saved to ./pcb3/normal_png/
# Converted 0872.JPG to 0872.png and saved to ./pcb3/normal_png/
# Converted 0873.JPG to 0873.png and saved to ./pcb3/normal_png/
# Converted 0874.JPG to 0874.png and saved to ./pcb3/normal_png/
# Converted 0875.JPG to 0875.png and saved to ./pcb3/normal_png/
# Converted 0876.JPG to 0876.png and saved to ./pcb3/normal_png/
# Converted 0877.JPG to 0877.png and saved to ./pcb3/normal_png/
# Converted 0878.JPG to 0878.png and saved to ./pcb3/normal_png/
# Converted 0879.JPG to 0879.png and saved to ./pcb3/normal_png/
# Converted 0880.JPG to 0880.png and saved to ./pcb3/normal_png/
# Converted 0881.JPG to 0881.png and saved to ./pcb3/normal_png/
# Converted 0882.JPG to 0882.png and saved to ./pcb3/normal_png/
# Converted 0883.JPG to 0883.png and saved to ./pcb3/normal_png/
# Converted 0884.JPG to 0884.png and saved to ./pcb3/normal_png/
# Converted 0885.JPG to 0885.png and saved to ./pcb3/normal_png/
# Converted 0886.JPG to 0886.png and saved to ./pcb3/normal_png/
# Converted 0887.JPG to 0887.png and saved to ./pcb3/normal_png/
# Converted 0888.JPG to 0888.png and saved to ./pcb3/normal_png/
# Converted 0889.JPG to 0889.png and saved to ./pcb3/normal_png/
# Converted 0890.JPG to 0890.png and saved to ./pcb3/normal_png/
# Converted 0891.JPG to 0891.png and saved to ./pcb3/normal_png/
# Converted 0892.JPG to 0892.png and saved to ./pcb3/normal_png/
# Converted 0893.JPG to 0893.png and saved to ./pcb3/normal_png/
# Converted 0894.JPG to 0894.png and saved to ./pcb3/normal_png/
# Converted 0895.JPG to 0895.png and saved to ./pcb3/normal_png/
# Converted 0896.JPG to 0896.png and saved to ./pcb3/normal_png/
# Converted 0897.JPG to 0897.png and saved to ./pcb3/normal_png/
# Converted 0898.JPG to 0898.png and saved to ./pcb3/normal_png/
# Converted 0899.JPG to 0899.png and saved to ./pcb3/normal_png/
# Converted 0900.JPG to 0900.png and saved to ./pcb3/normal_png/
# Converted 0901.JPG to 0901.png and saved to ./pcb3/normal_png/
# Converted 0902.JPG to 0902.png and saved to ./pcb3/normal_png/
# Converted 0903.JPG to 0903.png and saved to ./pcb3/normal_png/
# Converted 0904.JPG to 0904.png and saved to ./pcb3/normal_png/
# Converted 0905.JPG to 0905.png and saved to ./pcb3/normal_png/
# Converted 0906.JPG to 0906.png and saved to ./pcb3/normal_png/
# Converted 0907.JPG to 0907.png and saved to ./pcb3/normal_png/
# Converted 0908.JPG to 0908.png and saved to ./pcb3/normal_png/
# Converted 0909.JPG to 0909.png and saved to ./pcb3/normal_png/
# Converted 0910.JPG to 0910.png and saved to ./pcb3/normal_png/
# Converted 0911.JPG to 0911.png and saved to ./pcb3/normal_png/
# Converted 0912.JPG to 0912.png and saved to ./pcb3/normal_png/
# Converted 0913.JPG to 0913.png and saved to ./pcb3/normal_png/
# Converted 0914.JPG to 0914.png and saved to ./pcb3/normal_png/
# Converted 0915.JPG to 0915.png and saved to ./pcb3/normal_png/
# Converted 0916.JPG to 0916.png and saved to ./pcb3/normal_png/
# Converted 0917.JPG to 0917.png and saved to ./pcb3/normal_png/
# Converted 0918.JPG to 0918.png and saved to ./pcb3/normal_png/
# Converted 0919.JPG to 0919.png and saved to ./pcb3/normal_png/
# Converted 0920.JPG to 0920.png and saved to ./pcb3/normal_png/
# Converted 0921.JPG to 0921.png and saved to ./pcb3/normal_png/
# Converted 0922.JPG to 0922.png and saved to ./pcb3/normal_png/
# Converted 0923.JPG to 0923.png and saved to ./pcb3/normal_png/
# Converted 0924.JPG to 0924.png and saved to ./pcb3/normal_png/
# Converted 0925.JPG to 0925.png and saved to ./pcb3/normal_png/
# Converted 0926.JPG to 0926.png and saved to ./pcb3/normal_png/
# Converted 0927.JPG to 0927.png and saved to ./pcb3/normal_png/
# Converted 0928.JPG to 0928.png and saved to ./pcb3/normal_png/
# Converted 0929.JPG to 0929.png and saved to ./pcb3/normal_png/
# Converted 0930.JPG to 0930.png and saved to ./pcb3/normal_png/
# Converted 0931.JPG to 0931.png and saved to ./pcb3/normal_png/
# Converted 0932.JPG to 0932.png and saved to ./pcb3/normal_png/
# Converted 0933.JPG to 0933.png and saved to ./pcb3/normal_png/
# Converted 0934.JPG to 0934.png and saved to ./pcb3/normal_png/
# Converted 0935.JPG to 0935.png and saved to ./pcb3/normal_png/
# Converted 0936.JPG to 0936.png and saved to ./pcb3/normal_png/
# Converted 0937.JPG to 0937.png and saved to ./pcb3/normal_png/
# Converted 0938.JPG to 0938.png and saved to ./pcb3/normal_png/
# Converted 0939.JPG to 0939.png and saved to ./pcb3/normal_png/
# Converted 0940.JPG to 0940.png and saved to ./pcb3/normal_png/
# Converted 0941.JPG to 0941.png and saved to ./pcb3/normal_png/
# Converted 0942.JPG to 0942.png and saved to ./pcb3/normal_png/
# Converted 0943.JPG to 0943.png and saved to ./pcb3/normal_png/
# Converted 0944.JPG to 0944.png and saved to ./pcb3/normal_png/
# Converted 0945.JPG to 0945.png and saved to ./pcb3/normal_png/
# Converted 0946.JPG to 0946.png and saved to ./pcb3/normal_png/
# Converted 0947.JPG to 0947.png and saved to ./pcb3/normal_png/
# Converted 0948.JPG to 0948.png and saved to ./pcb3/normal_png/
# Converted 0949.JPG to 0949.png and saved to ./pcb3/normal_png/
# Converted 0950.JPG to 0950.png and saved to ./pcb3/normal_png/
# Converted 0951.JPG to 0951.png and saved to ./pcb3/normal_png/
# Converted 0952.JPG to 0952.png and saved to ./pcb3/normal_png/
# Converted 0953.JPG to 0953.png and saved to ./pcb3/normal_png/
# Converted 0954.JPG to 0954.png and saved to ./pcb3/normal_png/
# Converted 0955.JPG to 0955.png and saved to ./pcb3/normal_png/
# Converted 0956.JPG to 0956.png and saved to ./pcb3/normal_png/
# Converted 0957.JPG to 0957.png and saved to ./pcb3/normal_png/
# Converted 0958.JPG to 0958.png and saved to ./pcb3/normal_png/
# Converted 0959.JPG to 0959.png and saved to ./pcb3/normal_png/
# Converted 0960.JPG to 0960.png and saved to ./pcb3/normal_png/
# Converted 0961.JPG to 0961.png and saved to ./pcb3/normal_png/
# Converted 0962.JPG to 0962.png and saved to ./pcb3/normal_png/
# Converted 0963.JPG to 0963.png and saved to ./pcb3/normal_png/
# Converted 0964.JPG to 0964.png and saved to ./pcb3/normal_png/
# Converted 0965.JPG to 0965.png and saved to ./pcb3/normal_png/
# Converted 0966.JPG to 0966.png and saved to ./pcb3/normal_png/
# Converted 0967.JPG to 0967.png and saved to ./pcb3/normal_png/
# Converted 0968.JPG to 0968.png and saved to ./pcb3/normal_png/
# Converted 0969.JPG to 0969.png and saved to ./pcb3/normal_png/
# Converted 0970.JPG to 0970.png and saved to ./pcb3/normal_png/
# Converted 0971.JPG to 0971.png and saved to ./pcb3/normal_png/
# Converted 0972.JPG to 0972.png and saved to ./pcb3/normal_png/
# Converted 0973.JPG to 0973.png and saved to ./pcb3/normal_png/
# Converted 0974.JPG to 0974.png and saved to ./pcb3/normal_png/
# Converted 0975.JPG to 0975.png and saved to ./pcb3/normal_png/
# Converted 0976.JPG to 0976.png and saved to ./pcb3/normal_png/
# Converted 0977.JPG to 0977.png and saved to ./pcb3/normal_png/
# Converted 0978.JPG to 0978.png and saved to ./pcb3/normal_png/
# Converted 0979.JPG to 0979.png and saved to ./pcb3/normal_png/
# Converted 0980.JPG to 0980.png and saved to ./pcb3/normal_png/
# Converted 0981.JPG to 0981.png and saved to ./pcb3/normal_png/
# Converted 0982.JPG to 0982.png and saved to ./pcb3/normal_png/
# Converted 0983.JPG to 0983.png and saved to ./pcb3/normal_png/
# Converted 0984.JPG to 0984.png and saved to ./pcb3/normal_png/
# Converted 0985.JPG to 0985.png and saved to ./pcb3/normal_png/
# Converted 0986.JPG to 0986.png and saved to ./pcb3/normal_png/
# Converted 0987.JPG to 0987.png and saved to ./pcb3/normal_png/
# Converted 0988.JPG to 0988.png and saved to ./pcb3/normal_png/
# Converted 0989.JPG to 0989.png and saved to ./pcb3/normal_png/
# Converted 0990.JPG to 0990.png and saved to ./pcb3/normal_png/
# Converted 0991.JPG to 0991.png and saved to ./pcb3/normal_png/
# Converted 0992.JPG to 0992.png and saved to ./pcb3/normal_png/
# Converted 0993.JPG to 0993.png and saved to ./pcb3/normal_png/
# Converted 0994.JPG to 0994.png and saved to ./pcb3/normal_png/
# Converted 0995.JPG to 0995.png and saved to ./pcb3/normal_png/
# Converted 0996.JPG to 0996.png and saved to ./pcb3/normal_png/
# Converted 0997.JPG to 0997.png and saved to ./pcb3/normal_png/
# Converted 0998.JPG to 0998.png and saved to ./pcb3/normal_png/
# Converted 0999.JPG to 0999.png and saved to ./pcb3/normal_png/
# Converted 1000.JPG to 1000.png and saved to ./pcb3/normal_png/
# Converted 1001.JPG to 1001.png and saved to ./pcb3/normal_png/
# Converted 1002.JPG to 1002.png and saved to ./pcb3/normal_png/
# Converted 1003.JPG to 1003.png and saved to ./pcb3/normal_png/
# Converted 1004.JPG to 1004.png and saved to ./pcb3/normal_png/
# Converted 1005.JPG to 1005.png and saved to ./pcb3/normal_png/

# %% [markdown]
# ## Dataset: pcb3

# %%
from anomalib.data.folder import Folder
from anomalib.data.task_type import TaskType

datamodule = Folder(
    root=Path.cwd() / "pcb3",
    normal_dir="normal_png",
    abnormal_dir="anomaly_png",
    normal_split_ratio=0.2,
    image_size=(256, 256),
    train_batch_size=32,
    eval_batch_size=32,
    task=TaskType.CLASSIFICATION,
)
datamodule.setup()  # Split the data to train/val/test/prediction sets.
datamodule.prepare_data()  # Create train/val/test/predic dataloaders

i, data = next(enumerate(datamodule.val_dataloader()))
print(data.keys())
# Out:
# dict_keys(['image_path', 'label', 'image'])

# %%
# Check image size
print(data["image"].shape)
# Out:
# torch.Size([32, 3, 256, 256])

# %% [markdown]
# # Model: Padim, Backbone: ResNet-18

# %% [markdown]
# ## Prepare the Model

# %%
from anomalib.models import Padim

model = Padim(
    input_size=(256, 256),
    backbone="resnet18",
    layers=["layer1", "layer2", "layer3"],
)
# Out:
# C:\Users\Stellar\AppData\Roaming\Python\Python310\site-packages\torchmetrics\utilities\prints.py:36: DeprecationWarning: From v0.10 an `'Binary*'`, `'Multiclass*', `'Multilabel*'` version now exist of each classification metric. Moving forward we recommend using these versions. This base metric will still work as it did prior to v0.10 until v0.11. From v0.11 the `task` argument introduced in this metric will be required and the general order of arguments may change, such that this metric will just function as an single entrypoint to calling the three specialized versions.
#   warnings.warn(*args, **kwargs)
# C:\Users\Stellar\AppData\Roaming\Python\Python310\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# FeatureExtractor is deprecated. Use TimmFeatureExtractor instead. Both FeatureExtractor and TimmFeatureExtractor will be removed in a future release.

# %% [markdown]
# ## Prepare Callbacks

# %%
from anomalib.post_processing import NormalizationMethod, ThresholdMethod
from anomalib.utils.callbacks import (
    MetricsConfigurationCallback,
    MinMaxNormalizationCallback,
    PostProcessingConfigurationCallback,
)
from anomalib.utils.callbacks.export import ExportCallback, ExportMode

callbacks = [
    MetricsConfigurationCallback(
        task=TaskType.CLASSIFICATION,
        image_metrics=["AUROC", "AUPR"],
    ),
    ModelCheckpoint(
        mode="max",
        monitor="image_AUROC",
    ),
    PostProcessingConfigurationCallback(
        normalization_method=NormalizationMethod.MIN_MAX,
        threshold_method=ThresholdMethod.ADAPTIVE,
    ),
    MinMaxNormalizationCallback(),
    ExportCallback(
        input_size=(256, 256),
        dirpath=str(Path.cwd()),
        filename="model",
        export_mode=ExportMode.OPENVINO,
    ),
]

# %% [markdown]
# ## Training

# %%
trainer = Trainer(
    callbacks=callbacks,
    accelerator="auto",
    auto_scale_batch_size=False,
    check_val_every_n_epoch=1,
    devices=1,
    gpus=None,
    max_epochs=10,
    num_sanity_val_steps=0,
    val_check_interval=1.0,
)
trainer.fit(model=model, datamodule=datamodule)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# C:\Users\Stellar\AppData\Roaming\Python\Python310\site-packages\torchmetrics\utilities\prints.py:36: DeprecationWarning: From v0.10 an `'Binary*'`, `'Multiclass*', `'Multilabel*'` version now exist of each classification metric. Moving forward we recommend using these versions. This base metric will still work as it did prior to v0.10 until v0.11. From v0.11 the `task` argument introduced in this metric will be required and the general order of arguments may change, such that this metric will just function as an single entrypoint to calling the three specialized versions.
#   warnings.warn(*args, **kwargs)
# C:\Users\Stellar\AppData\Roaming\Python\Python310\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# C:\Users\Stellar\AppData\Roaming\Python\Python310\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# C:\Users\Stellar\AppData\Roaming\Python\Python310\site-packages\pytorch_lightning\core\optimizer.py:183: UserWarning: `LightningModule.configure_optimizers` returned `None`, this fit will run with no optimizer
#   rank_zero_warn(
#
#   | Name                  | Type                     | Params
# -------------------------------------------------------------------
# 0 | image_threshold       | AnomalyScoreThreshold    | 0
# 1 | pixel_threshold       | AnomalyScoreThreshold    | 0
# 2 | model                 | PadimModel               | 2.8 M
# 3 | image_metrics         | AnomalibMetricCollection | 0
# 4 | pixel_metrics         | AnomalibMetricCollection | 0
# 5 | normalization_metrics | MinMax                   | 0
# -------------------------------------------------------------------
# 2.8 M     Trainable params
# 0         Non-trainable params
# 2.8 M     Total params
# 11.131    Total estimated model params size (MB)
# C:\Users\Stellar\mambaforge\envs\nlp\lib\site-packages\torch\utils\tensorboard\__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(
# C:\Users\Stellar\AppData\Roaming\Python\Python310\site-packages\pytorch_lightning\trainer\trainer.py:1609: PossibleUserWarning: The number of training batches (26) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# C:\Users\Stellar\AppData\Roaming\Python\Python310\site-packages\pytorch_lightning\loops\optimization\optimizer_loop.py:138: UserWarning: `training_step` returned `None`. If this was on purpose, ignore this warning...
#   self.warning_cache.warn("`training_step` returned `None`. If this was on purpose, ignore this warning...")
# Validation: 0it [00:00, ?it/s]
# C:\Users\Stellar\AppData\Roaming\Python\Python310\site-packages\torchmetrics\utilities\prints.py:36: DeprecationWarning: `torchmetrics.functional.auc` has been move to `torchmetrics.utilities.compute` in v0.10 and will be removed in v0.11.
#   warnings.warn(*args, **kwargs)
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:01, ?it/s]
# Validation: 0it [00:00, ?it/s]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# C:\Users\Stellar\mambaforge\envs\nlp\lib\site-packages\torch\onnx\_internal\jit_utils.py:306: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\jit\passes\onnx\constant_fold.cpp:181.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# C:\Users\Stellar\mambaforge\envs\nlp\lib\site-packages\torch\onnx\utils.py:689: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\jit\passes\onnx\constant_fold.cpp:181.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# C:\Users\Stellar\mambaforge\envs\nlp\lib\site-packages\torch\onnx\utils.py:1186: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\jit\passes\onnx\constant_fold.cpp:181.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# ================ Diagnostic Run torch.onnx.export version 2.0.0 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %% [markdown]
# ## Evaluation

# %%
# Validation
test_results = trainer.test(model=model, datamodule=datamodule)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUPR         │    0.5664681196212769     │
# │        image_AUROC        │    0.7452475428581238     │
# └───────────────────────────┴───────────────────────────┘

# %% [markdown]
# ## Inference using OpenVino

# %% [markdown]
# ### Load a Test Image

# %%
from matplotlib import pyplot as plt

image_path = "./pcb3/anomaly_png/000.png"
image = read_image(path="./pcb3/anomaly_png/000.png")
plt.imshow(image)

# %% [markdown]
# ### Load the OpenVINO Model

# %%
openvino_model_path = Path.cwd() / "weights" / "openvino" / "model.bin"
metadata_path = Path.cwd() / "weights" / "openvino" / "metadata.json"
print(openvino_model_path.exists(), metadata_path.exists())
# Out:
# True True

# %%
inferencer = OpenVINOInferencer(
    path=openvino_model_path,  # Path to the OpenVINO IR model.
    metadata=metadata_path,  # Path to the metadata file.
    device="CPU",  # We would like to run it on an Intel CPU.
)

# %% [markdown]
# ### Perform Inference

# %%
print(image.shape)
predictions = inferencer.predict(image=image)
# Out:
# (960, 1562, 3)

# %% [markdown]
# ### Visualizing Inference Results

# %% [markdown]
# #### Example 1

# %%
from anomalib.post_processing import Visualizer, VisualizationMode
from PIL import Image

visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.CLASSIFICATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x500>

# %%
visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.SEGMENTATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x500>

# %% [markdown]
# #### Example 2

# %%
image = read_image(path="./pcb3/anomaly_png/005.png")
predictions = inferencer.predict(image=image)
visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.CLASSIFICATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x500>

# %%
visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.SEGMENTATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x500>

# %% [markdown]
# #### Example 3

# %%
image = read_image(path="./pcb3/anomaly_png/023.png")
predictions = inferencer.predict(image=image)
visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.CLASSIFICATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x500>

# %%
visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.SEGMENTATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x500>

# %% [markdown]
# #### Example 4

# %%
image = read_image(path="./pcb3/anomaly_png/048.png")
predictions = inferencer.predict(image=image)
visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.CLASSIFICATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x500>

# %%
visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.SEGMENTATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x500>
