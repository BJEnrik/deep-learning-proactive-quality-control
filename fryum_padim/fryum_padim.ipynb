# %% [markdown]
# # Libraries

# %%
from pathlib import Path

from anomalib.data.utils import read_image
from anomalib.deploy import OpenVINOInferencer
from pytorch_lightning import Trainer
from pytorch_lightning.callbacks import ModelCheckpoint

import os
from PIL import Image

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Converting from JPG to png

# %%
source_directory = "./fryum/Data/Images/Anomaly/"
destination_directory = "./fryum/anomaly_png/"

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_directory):
    os.makedirs(destination_directory)

# Iterate over the files in the source directory
for filename in os.listdir(source_directory):
    if filename.endswith(".JPG"):
        # Open the image file
        image_path = os.path.join(source_directory, filename)
        image = Image.open(image_path)

        # Convert and save the image as .png in the destination directory
        new_filename = os.path.splitext(filename)[0] + ".png"
        destination_path = os.path.join(destination_directory, new_filename)
        image.save(destination_path, "PNG")

        print(f"Converted {filename} to {new_filename} and saved to {destination_directory}")
# Out:
# Converted 000.JPG to 000.png and saved to ./fryum/anomaly_png/
# Converted 001.JPG to 001.png and saved to ./fryum/anomaly_png/
# Converted 002.JPG to 002.png and saved to ./fryum/anomaly_png/
# Converted 003.JPG to 003.png and saved to ./fryum/anomaly_png/
# Converted 004.JPG to 004.png and saved to ./fryum/anomaly_png/
# Converted 005.JPG to 005.png and saved to ./fryum/anomaly_png/
# Converted 006.JPG to 006.png and saved to ./fryum/anomaly_png/
# Converted 007.JPG to 007.png and saved to ./fryum/anomaly_png/
# Converted 008.JPG to 008.png and saved to ./fryum/anomaly_png/
# Converted 009.JPG to 009.png and saved to ./fryum/anomaly_png/
# Converted 010.JPG to 010.png and saved to ./fryum/anomaly_png/
# Converted 011.JPG to 011.png and saved to ./fryum/anomaly_png/
# Converted 012.JPG to 012.png and saved to ./fryum/anomaly_png/
# Converted 013.JPG to 013.png and saved to ./fryum/anomaly_png/
# Converted 014.JPG to 014.png and saved to ./fryum/anomaly_png/
# Converted 015.JPG to 015.png and saved to ./fryum/anomaly_png/
# Converted 016.JPG to 016.png and saved to ./fryum/anomaly_png/
# Converted 017.JPG to 017.png and saved to ./fryum/anomaly_png/
# Converted 018.JPG to 018.png and saved to ./fryum/anomaly_png/
# Converted 019.JPG to 019.png and saved to ./fryum/anomaly_png/
# Converted 020.JPG to 020.png and saved to ./fryum/anomaly_png/
# Converted 021.JPG to 021.png and saved to ./fryum/anomaly_png/
# Converted 022.JPG to 022.png and saved to ./fryum/anomaly_png/
# Converted 023.JPG to 023.png and saved to ./fryum/anomaly_png/
# Converted 024.JPG to 024.png and saved to ./fryum/anomaly_png/
# Converted 025.JPG to 025.png and saved to ./fryum/anomaly_png/
# Converted 026.JPG to 026.png and saved to ./fryum/anomaly_png/
# Converted 027.JPG to 027.png and saved to ./fryum/anomaly_png/
# Converted 028.JPG to 028.png and saved to ./fryum/anomaly_png/
# Converted 029.JPG to 029.png and saved to ./fryum/anomaly_png/
# Converted 030.JPG to 030.png and saved to ./fryum/anomaly_png/
# Converted 031.JPG to 031.png and saved to ./fryum/anomaly_png/
# Converted 032.JPG to 032.png and saved to ./fryum/anomaly_png/
# Converted 033.JPG to 033.png and saved to ./fryum/anomaly_png/
# Converted 034.JPG to 034.png and saved to ./fryum/anomaly_png/
# Converted 035.JPG to 035.png and saved to ./fryum/anomaly_png/
# Converted 036.JPG to 036.png and saved to ./fryum/anomaly_png/
# Converted 037.JPG to 037.png and saved to ./fryum/anomaly_png/
# Converted 038.JPG to 038.png and saved to ./fryum/anomaly_png/
# Converted 039.JPG to 039.png and saved to ./fryum/anomaly_png/
# Converted 040.JPG to 040.png and saved to ./fryum/anomaly_png/
# Converted 041.JPG to 041.png and saved to ./fryum/anomaly_png/
# Converted 042.JPG to 042.png and saved to ./fryum/anomaly_png/
# Converted 043.JPG to 043.png and saved to ./fryum/anomaly_png/
# Converted 044.JPG to 044.png and saved to ./fryum/anomaly_png/
# Converted 045.JPG to 045.png and saved to ./fryum/anomaly_png/
# Converted 046.JPG to 046.png and saved to ./fryum/anomaly_png/
# Converted 047.JPG to 047.png and saved to ./fryum/anomaly_png/
# Converted 048.JPG to 048.png and saved to ./fryum/anomaly_png/
# Converted 049.JPG to 049.png and saved to ./fryum/anomaly_png/
# Converted 050.JPG to 050.png and saved to ./fryum/anomaly_png/
# Converted 051.JPG to 051.png and saved to ./fryum/anomaly_png/
# Converted 052.JPG to 052.png and saved to ./fryum/anomaly_png/
# Converted 053.JPG to 053.png and saved to ./fryum/anomaly_png/
# Converted 054.JPG to 054.png and saved to ./fryum/anomaly_png/
# Converted 055.JPG to 055.png and saved to ./fryum/anomaly_png/
# Converted 056.JPG to 056.png and saved to ./fryum/anomaly_png/
# Converted 057.JPG to 057.png and saved to ./fryum/anomaly_png/
# Converted 058.JPG to 058.png and saved to ./fryum/anomaly_png/
# Converted 059.JPG to 059.png and saved to ./fryum/anomaly_png/
# Converted 060.JPG to 060.png and saved to ./fryum/anomaly_png/
# Converted 061.JPG to 061.png and saved to ./fryum/anomaly_png/
# Converted 062.JPG to 062.png and saved to ./fryum/anomaly_png/
# Converted 063.JPG to 063.png and saved to ./fryum/anomaly_png/
# Converted 064.JPG to 064.png and saved to ./fryum/anomaly_png/
# Converted 065.JPG to 065.png and saved to ./fryum/anomaly_png/
# Converted 066.JPG to 066.png and saved to ./fryum/anomaly_png/
# Converted 067.JPG to 067.png and saved to ./fryum/anomaly_png/
# Converted 068.JPG to 068.png and saved to ./fryum/anomaly_png/
# Converted 069.JPG to 069.png and saved to ./fryum/anomaly_png/
# Converted 070.JPG to 070.png and saved to ./fryum/anomaly_png/
# Converted 071.JPG to 071.png and saved to ./fryum/anomaly_png/
# Converted 072.JPG to 072.png and saved to ./fryum/anomaly_png/
# Converted 073.JPG to 073.png and saved to ./fryum/anomaly_png/
# Converted 074.JPG to 074.png and saved to ./fryum/anomaly_png/
# Converted 075.JPG to 075.png and saved to ./fryum/anomaly_png/
# Converted 076.JPG to 076.png and saved to ./fryum/anomaly_png/
# Converted 077.JPG to 077.png and saved to ./fryum/anomaly_png/
# Converted 078.JPG to 078.png and saved to ./fryum/anomaly_png/
# Converted 079.JPG to 079.png and saved to ./fryum/anomaly_png/
# Converted 080.JPG to 080.png and saved to ./fryum/anomaly_png/
# Converted 081.JPG to 081.png and saved to ./fryum/anomaly_png/
# Converted 082.JPG to 082.png and saved to ./fryum/anomaly_png/
# Converted 083.JPG to 083.png and saved to ./fryum/anomaly_png/
# Converted 084.JPG to 084.png and saved to ./fryum/anomaly_png/
# Converted 085.JPG to 085.png and saved to ./fryum/anomaly_png/
# Converted 086.JPG to 086.png and saved to ./fryum/anomaly_png/
# Converted 087.JPG to 087.png and saved to ./fryum/anomaly_png/
# Converted 088.JPG to 088.png and saved to ./fryum/anomaly_png/
# Converted 089.JPG to 089.png and saved to ./fryum/anomaly_png/
# Converted 090.JPG to 090.png and saved to ./fryum/anomaly_png/
# Converted 091.JPG to 091.png and saved to ./fryum/anomaly_png/
# Converted 092.JPG to 092.png and saved to ./fryum/anomaly_png/
# Converted 093.JPG to 093.png and saved to ./fryum/anomaly_png/
# Converted 094.JPG to 094.png and saved to ./fryum/anomaly_png/
# Converted 095.JPG to 095.png and saved to ./fryum/anomaly_png/
# Converted 096.JPG to 096.png and saved to ./fryum/anomaly_png/
# Converted 097.JPG to 097.png and saved to ./fryum/anomaly_png/
# Converted 098.JPG to 098.png and saved to ./fryum/anomaly_png/
# Converted 099.JPG to 099.png and saved to ./fryum/anomaly_png/

# %%
source_directory = "./fryum/Data/Images/Normal"
destination_directory = "./fryum/normal_png/"

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_directory):
    os.makedirs(destination_directory)

# Iterate over the files in the source directory
for filename in os.listdir(source_directory):
    if filename.endswith(".JPG"):
        # Open the image file
        image_path = os.path.join(source_directory, filename)
        image = Image.open(image_path)

        # Convert and save the image as .png in the destination directory
        new_filename = os.path.splitext(filename)[0] + ".png"
        destination_path = os.path.join(destination_directory, new_filename)
        image.save(destination_path, "PNG")

        print(f"Converted {filename} to {new_filename} and saved to {destination_directory}")
# Out:
# Converted 000.JPG to 000.png and saved to ./fryum/normal_png/
# Converted 001.JPG to 001.png and saved to ./fryum/normal_png/
# Converted 002.JPG to 002.png and saved to ./fryum/normal_png/
# Converted 003.JPG to 003.png and saved to ./fryum/normal_png/
# Converted 004.JPG to 004.png and saved to ./fryum/normal_png/
# Converted 005.JPG to 005.png and saved to ./fryum/normal_png/
# Converted 006.JPG to 006.png and saved to ./fryum/normal_png/
# Converted 007.JPG to 007.png and saved to ./fryum/normal_png/
# Converted 008.JPG to 008.png and saved to ./fryum/normal_png/
# Converted 009.JPG to 009.png and saved to ./fryum/normal_png/
# Converted 010.JPG to 010.png and saved to ./fryum/normal_png/
# Converted 011.JPG to 011.png and saved to ./fryum/normal_png/
# Converted 012.JPG to 012.png and saved to ./fryum/normal_png/
# Converted 013.JPG to 013.png and saved to ./fryum/normal_png/
# Converted 014.JPG to 014.png and saved to ./fryum/normal_png/
# Converted 015.JPG to 015.png and saved to ./fryum/normal_png/
# Converted 016.JPG to 016.png and saved to ./fryum/normal_png/
# Converted 017.JPG to 017.png and saved to ./fryum/normal_png/
# Converted 018.JPG to 018.png and saved to ./fryum/normal_png/
# Converted 019.JPG to 019.png and saved to ./fryum/normal_png/
# Converted 020.JPG to 020.png and saved to ./fryum/normal_png/
# Converted 021.JPG to 021.png and saved to ./fryum/normal_png/
# Converted 022.JPG to 022.png and saved to ./fryum/normal_png/
# Converted 023.JPG to 023.png and saved to ./fryum/normal_png/
# Converted 024.JPG to 024.png and saved to ./fryum/normal_png/
# Converted 025.JPG to 025.png and saved to ./fryum/normal_png/
# Converted 026.JPG to 026.png and saved to ./fryum/normal_png/
# Converted 027.JPG to 027.png and saved to ./fryum/normal_png/
# Converted 028.JPG to 028.png and saved to ./fryum/normal_png/
# Converted 029.JPG to 029.png and saved to ./fryum/normal_png/
# Converted 030.JPG to 030.png and saved to ./fryum/normal_png/
# Converted 031.JPG to 031.png and saved to ./fryum/normal_png/
# Converted 032.JPG to 032.png and saved to ./fryum/normal_png/
# Converted 033.JPG to 033.png and saved to ./fryum/normal_png/
# Converted 034.JPG to 034.png and saved to ./fryum/normal_png/
# Converted 035.JPG to 035.png and saved to ./fryum/normal_png/
# Converted 036.JPG to 036.png and saved to ./fryum/normal_png/
# Converted 037.JPG to 037.png and saved to ./fryum/normal_png/
# Converted 038.JPG to 038.png and saved to ./fryum/normal_png/
# Converted 039.JPG to 039.png and saved to ./fryum/normal_png/
# Converted 040.JPG to 040.png and saved to ./fryum/normal_png/
# Converted 041.JPG to 041.png and saved to ./fryum/normal_png/
# Converted 042.JPG to 042.png and saved to ./fryum/normal_png/
# Converted 043.JPG to 043.png and saved to ./fryum/normal_png/
# Converted 044.JPG to 044.png and saved to ./fryum/normal_png/
# Converted 045.JPG to 045.png and saved to ./fryum/normal_png/
# Converted 046.JPG to 046.png and saved to ./fryum/normal_png/
# Converted 047.JPG to 047.png and saved to ./fryum/normal_png/
# Converted 048.JPG to 048.png and saved to ./fryum/normal_png/
# Converted 049.JPG to 049.png and saved to ./fryum/normal_png/
# Converted 050.JPG to 050.png and saved to ./fryum/normal_png/
# Converted 051.JPG to 051.png and saved to ./fryum/normal_png/
# Converted 052.JPG to 052.png and saved to ./fryum/normal_png/
# Converted 053.JPG to 053.png and saved to ./fryum/normal_png/
# Converted 054.JPG to 054.png and saved to ./fryum/normal_png/
# Converted 055.JPG to 055.png and saved to ./fryum/normal_png/
# Converted 056.JPG to 056.png and saved to ./fryum/normal_png/
# Converted 057.JPG to 057.png and saved to ./fryum/normal_png/
# Converted 058.JPG to 058.png and saved to ./fryum/normal_png/
# Converted 059.JPG to 059.png and saved to ./fryum/normal_png/
# Converted 060.JPG to 060.png and saved to ./fryum/normal_png/
# Converted 061.JPG to 061.png and saved to ./fryum/normal_png/
# Converted 062.JPG to 062.png and saved to ./fryum/normal_png/
# Converted 063.JPG to 063.png and saved to ./fryum/normal_png/
# Converted 064.JPG to 064.png and saved to ./fryum/normal_png/
# Converted 065.JPG to 065.png and saved to ./fryum/normal_png/
# Converted 066.JPG to 066.png and saved to ./fryum/normal_png/
# Converted 067.JPG to 067.png and saved to ./fryum/normal_png/
# Converted 068.JPG to 068.png and saved to ./fryum/normal_png/
# Converted 069.JPG to 069.png and saved to ./fryum/normal_png/
# Converted 070.JPG to 070.png and saved to ./fryum/normal_png/
# Converted 071.JPG to 071.png and saved to ./fryum/normal_png/
# Converted 072.JPG to 072.png and saved to ./fryum/normal_png/
# Converted 073.JPG to 073.png and saved to ./fryum/normal_png/
# Converted 074.JPG to 074.png and saved to ./fryum/normal_png/
# Converted 075.JPG to 075.png and saved to ./fryum/normal_png/
# Converted 076.JPG to 076.png and saved to ./fryum/normal_png/
# Converted 077.JPG to 077.png and saved to ./fryum/normal_png/
# Converted 078.JPG to 078.png and saved to ./fryum/normal_png/
# Converted 079.JPG to 079.png and saved to ./fryum/normal_png/
# Converted 080.JPG to 080.png and saved to ./fryum/normal_png/
# Converted 081.JPG to 081.png and saved to ./fryum/normal_png/
# Converted 082.JPG to 082.png and saved to ./fryum/normal_png/
# Converted 083.JPG to 083.png and saved to ./fryum/normal_png/
# Converted 084.JPG to 084.png and saved to ./fryum/normal_png/
# Converted 085.JPG to 085.png and saved to ./fryum/normal_png/
# Converted 086.JPG to 086.png and saved to ./fryum/normal_png/
# Converted 087.JPG to 087.png and saved to ./fryum/normal_png/
# Converted 088.JPG to 088.png and saved to ./fryum/normal_png/
# Converted 089.JPG to 089.png and saved to ./fryum/normal_png/
# Converted 090.JPG to 090.png and saved to ./fryum/normal_png/
# Converted 091.JPG to 091.png and saved to ./fryum/normal_png/
# Converted 092.JPG to 092.png and saved to ./fryum/normal_png/
# Converted 093.JPG to 093.png and saved to ./fryum/normal_png/
# Converted 094.JPG to 094.png and saved to ./fryum/normal_png/
# Converted 095.JPG to 095.png and saved to ./fryum/normal_png/
# Converted 096.JPG to 096.png and saved to ./fryum/normal_png/
# Converted 097.JPG to 097.png and saved to ./fryum/normal_png/
# Converted 098.JPG to 098.png and saved to ./fryum/normal_png/
# Converted 099.JPG to 099.png and saved to ./fryum/normal_png/
# Converted 100.JPG to 100.png and saved to ./fryum/normal_png/
# Converted 101.JPG to 101.png and saved to ./fryum/normal_png/
# Converted 102.JPG to 102.png and saved to ./fryum/normal_png/
# Converted 103.JPG to 103.png and saved to ./fryum/normal_png/
# Converted 104.JPG to 104.png and saved to ./fryum/normal_png/
# Converted 105.JPG to 105.png and saved to ./fryum/normal_png/
# Converted 106.JPG to 106.png and saved to ./fryum/normal_png/
# Converted 107.JPG to 107.png and saved to ./fryum/normal_png/
# Converted 108.JPG to 108.png and saved to ./fryum/normal_png/
# Converted 109.JPG to 109.png and saved to ./fryum/normal_png/
# Converted 110.JPG to 110.png and saved to ./fryum/normal_png/
# Converted 111.JPG to 111.png and saved to ./fryum/normal_png/
# Converted 112.JPG to 112.png and saved to ./fryum/normal_png/
# Converted 113.JPG to 113.png and saved to ./fryum/normal_png/
# Converted 114.JPG to 114.png and saved to ./fryum/normal_png/
# Converted 115.JPG to 115.png and saved to ./fryum/normal_png/
# Converted 116.JPG to 116.png and saved to ./fryum/normal_png/
# Converted 117.JPG to 117.png and saved to ./fryum/normal_png/
# Converted 118.JPG to 118.png and saved to ./fryum/normal_png/
# Converted 119.JPG to 119.png and saved to ./fryum/normal_png/
# Converted 120.JPG to 120.png and saved to ./fryum/normal_png/
# Converted 121.JPG to 121.png and saved to ./fryum/normal_png/
# Converted 122.JPG to 122.png and saved to ./fryum/normal_png/
# Converted 123.JPG to 123.png and saved to ./fryum/normal_png/
# Converted 124.JPG to 124.png and saved to ./fryum/normal_png/
# Converted 125.JPG to 125.png and saved to ./fryum/normal_png/
# Converted 126.JPG to 126.png and saved to ./fryum/normal_png/
# Converted 127.JPG to 127.png and saved to ./fryum/normal_png/
# Converted 128.JPG to 128.png and saved to ./fryum/normal_png/
# Converted 129.JPG to 129.png and saved to ./fryum/normal_png/
# Converted 130.JPG to 130.png and saved to ./fryum/normal_png/
# Converted 131.JPG to 131.png and saved to ./fryum/normal_png/
# Converted 132.JPG to 132.png and saved to ./fryum/normal_png/
# Converted 133.JPG to 133.png and saved to ./fryum/normal_png/
# Converted 134.JPG to 134.png and saved to ./fryum/normal_png/
# Converted 135.JPG to 135.png and saved to ./fryum/normal_png/
# Converted 136.JPG to 136.png and saved to ./fryum/normal_png/
# Converted 137.JPG to 137.png and saved to ./fryum/normal_png/
# Converted 138.JPG to 138.png and saved to ./fryum/normal_png/
# Converted 139.JPG to 139.png and saved to ./fryum/normal_png/
# Converted 140.JPG to 140.png and saved to ./fryum/normal_png/
# Converted 141.JPG to 141.png and saved to ./fryum/normal_png/
# Converted 142.JPG to 142.png and saved to ./fryum/normal_png/
# Converted 143.JPG to 143.png and saved to ./fryum/normal_png/
# Converted 144.JPG to 144.png and saved to ./fryum/normal_png/
# Converted 145.JPG to 145.png and saved to ./fryum/normal_png/
# Converted 146.JPG to 146.png and saved to ./fryum/normal_png/
# Converted 147.JPG to 147.png and saved to ./fryum/normal_png/
# Converted 148.JPG to 148.png and saved to ./fryum/normal_png/
# Converted 149.JPG to 149.png and saved to ./fryum/normal_png/
# Converted 150.JPG to 150.png and saved to ./fryum/normal_png/
# Converted 151.JPG to 151.png and saved to ./fryum/normal_png/
# Converted 152.JPG to 152.png and saved to ./fryum/normal_png/
# Converted 153.JPG to 153.png and saved to ./fryum/normal_png/
# Converted 154.JPG to 154.png and saved to ./fryum/normal_png/
# Converted 155.JPG to 155.png and saved to ./fryum/normal_png/
# Converted 156.JPG to 156.png and saved to ./fryum/normal_png/
# Converted 157.JPG to 157.png and saved to ./fryum/normal_png/
# Converted 158.JPG to 158.png and saved to ./fryum/normal_png/
# Converted 159.JPG to 159.png and saved to ./fryum/normal_png/
# Converted 160.JPG to 160.png and saved to ./fryum/normal_png/
# Converted 161.JPG to 161.png and saved to ./fryum/normal_png/
# Converted 162.JPG to 162.png and saved to ./fryum/normal_png/
# Converted 163.JPG to 163.png and saved to ./fryum/normal_png/
# Converted 164.JPG to 164.png and saved to ./fryum/normal_png/
# Converted 165.JPG to 165.png and saved to ./fryum/normal_png/
# Converted 166.JPG to 166.png and saved to ./fryum/normal_png/
# Converted 167.JPG to 167.png and saved to ./fryum/normal_png/
# Converted 168.JPG to 168.png and saved to ./fryum/normal_png/
# Converted 169.JPG to 169.png and saved to ./fryum/normal_png/
# Converted 170.JPG to 170.png and saved to ./fryum/normal_png/
# Converted 171.JPG to 171.png and saved to ./fryum/normal_png/
# Converted 172.JPG to 172.png and saved to ./fryum/normal_png/
# Converted 173.JPG to 173.png and saved to ./fryum/normal_png/
# Converted 174.JPG to 174.png and saved to ./fryum/normal_png/
# Converted 175.JPG to 175.png and saved to ./fryum/normal_png/
# Converted 176.JPG to 176.png and saved to ./fryum/normal_png/
# Converted 177.JPG to 177.png and saved to ./fryum/normal_png/
# Converted 178.JPG to 178.png and saved to ./fryum/normal_png/
# Converted 179.JPG to 179.png and saved to ./fryum/normal_png/
# Converted 180.JPG to 180.png and saved to ./fryum/normal_png/
# Converted 181.JPG to 181.png and saved to ./fryum/normal_png/
# Converted 182.JPG to 182.png and saved to ./fryum/normal_png/
# Converted 183.JPG to 183.png and saved to ./fryum/normal_png/
# Converted 184.JPG to 184.png and saved to ./fryum/normal_png/
# Converted 185.JPG to 185.png and saved to ./fryum/normal_png/
# Converted 186.JPG to 186.png and saved to ./fryum/normal_png/
# Converted 187.JPG to 187.png and saved to ./fryum/normal_png/
# Converted 188.JPG to 188.png and saved to ./fryum/normal_png/
# Converted 189.JPG to 189.png and saved to ./fryum/normal_png/
# Converted 190.JPG to 190.png and saved to ./fryum/normal_png/
# Converted 191.JPG to 191.png and saved to ./fryum/normal_png/
# Converted 192.JPG to 192.png and saved to ./fryum/normal_png/
# Converted 193.JPG to 193.png and saved to ./fryum/normal_png/
# Converted 194.JPG to 194.png and saved to ./fryum/normal_png/
# Converted 195.JPG to 195.png and saved to ./fryum/normal_png/
# Converted 196.JPG to 196.png and saved to ./fryum/normal_png/
# Converted 197.JPG to 197.png and saved to ./fryum/normal_png/
# Converted 198.JPG to 198.png and saved to ./fryum/normal_png/
# Converted 199.JPG to 199.png and saved to ./fryum/normal_png/
# Converted 200.JPG to 200.png and saved to ./fryum/normal_png/
# Converted 201.JPG to 201.png and saved to ./fryum/normal_png/
# Converted 202.JPG to 202.png and saved to ./fryum/normal_png/
# Converted 203.JPG to 203.png and saved to ./fryum/normal_png/
# Converted 204.JPG to 204.png and saved to ./fryum/normal_png/
# Converted 205.JPG to 205.png and saved to ./fryum/normal_png/
# Converted 206.JPG to 206.png and saved to ./fryum/normal_png/
# Converted 207.JPG to 207.png and saved to ./fryum/normal_png/
# Converted 208.JPG to 208.png and saved to ./fryum/normal_png/
# Converted 209.JPG to 209.png and saved to ./fryum/normal_png/
# Converted 210.JPG to 210.png and saved to ./fryum/normal_png/
# Converted 211.JPG to 211.png and saved to ./fryum/normal_png/
# Converted 212.JPG to 212.png and saved to ./fryum/normal_png/
# Converted 213.JPG to 213.png and saved to ./fryum/normal_png/
# Converted 214.JPG to 214.png and saved to ./fryum/normal_png/
# Converted 215.JPG to 215.png and saved to ./fryum/normal_png/
# Converted 216.JPG to 216.png and saved to ./fryum/normal_png/
# Converted 217.JPG to 217.png and saved to ./fryum/normal_png/
# Converted 218.JPG to 218.png and saved to ./fryum/normal_png/
# Converted 219.JPG to 219.png and saved to ./fryum/normal_png/
# Converted 220.JPG to 220.png and saved to ./fryum/normal_png/
# Converted 221.JPG to 221.png and saved to ./fryum/normal_png/
# Converted 222.JPG to 222.png and saved to ./fryum/normal_png/
# Converted 223.JPG to 223.png and saved to ./fryum/normal_png/
# Converted 224.JPG to 224.png and saved to ./fryum/normal_png/
# Converted 225.JPG to 225.png and saved to ./fryum/normal_png/
# Converted 226.JPG to 226.png and saved to ./fryum/normal_png/
# Converted 227.JPG to 227.png and saved to ./fryum/normal_png/
# Converted 228.JPG to 228.png and saved to ./fryum/normal_png/
# Converted 229.JPG to 229.png and saved to ./fryum/normal_png/
# Converted 230.JPG to 230.png and saved to ./fryum/normal_png/
# Converted 231.JPG to 231.png and saved to ./fryum/normal_png/
# Converted 232.JPG to 232.png and saved to ./fryum/normal_png/
# Converted 233.JPG to 233.png and saved to ./fryum/normal_png/
# Converted 234.JPG to 234.png and saved to ./fryum/normal_png/
# Converted 235.JPG to 235.png and saved to ./fryum/normal_png/
# Converted 236.JPG to 236.png and saved to ./fryum/normal_png/
# Converted 237.JPG to 237.png and saved to ./fryum/normal_png/
# Converted 238.JPG to 238.png and saved to ./fryum/normal_png/
# Converted 239.JPG to 239.png and saved to ./fryum/normal_png/
# Converted 240.JPG to 240.png and saved to ./fryum/normal_png/
# Converted 241.JPG to 241.png and saved to ./fryum/normal_png/
# Converted 242.JPG to 242.png and saved to ./fryum/normal_png/
# Converted 243.JPG to 243.png and saved to ./fryum/normal_png/
# Converted 244.JPG to 244.png and saved to ./fryum/normal_png/
# Converted 245.JPG to 245.png and saved to ./fryum/normal_png/
# Converted 246.JPG to 246.png and saved to ./fryum/normal_png/
# Converted 247.JPG to 247.png and saved to ./fryum/normal_png/
# Converted 248.JPG to 248.png and saved to ./fryum/normal_png/
# Converted 249.JPG to 249.png and saved to ./fryum/normal_png/
# Converted 250.JPG to 250.png and saved to ./fryum/normal_png/
# Converted 251.JPG to 251.png and saved to ./fryum/normal_png/
# Converted 252.JPG to 252.png and saved to ./fryum/normal_png/
# Converted 253.JPG to 253.png and saved to ./fryum/normal_png/
# Converted 254.JPG to 254.png and saved to ./fryum/normal_png/
# Converted 255.JPG to 255.png and saved to ./fryum/normal_png/
# Converted 256.JPG to 256.png and saved to ./fryum/normal_png/
# Converted 257.JPG to 257.png and saved to ./fryum/normal_png/
# Converted 258.JPG to 258.png and saved to ./fryum/normal_png/
# Converted 259.JPG to 259.png and saved to ./fryum/normal_png/
# Converted 260.JPG to 260.png and saved to ./fryum/normal_png/
# Converted 261.JPG to 261.png and saved to ./fryum/normal_png/
# Converted 262.JPG to 262.png and saved to ./fryum/normal_png/
# Converted 263.JPG to 263.png and saved to ./fryum/normal_png/
# Converted 264.JPG to 264.png and saved to ./fryum/normal_png/
# Converted 265.JPG to 265.png and saved to ./fryum/normal_png/
# Converted 266.JPG to 266.png and saved to ./fryum/normal_png/
# Converted 267.JPG to 267.png and saved to ./fryum/normal_png/
# Converted 268.JPG to 268.png and saved to ./fryum/normal_png/
# Converted 269.JPG to 269.png and saved to ./fryum/normal_png/
# Converted 270.JPG to 270.png and saved to ./fryum/normal_png/
# Converted 271.JPG to 271.png and saved to ./fryum/normal_png/
# Converted 272.JPG to 272.png and saved to ./fryum/normal_png/
# Converted 273.JPG to 273.png and saved to ./fryum/normal_png/
# Converted 274.JPG to 274.png and saved to ./fryum/normal_png/
# Converted 275.JPG to 275.png and saved to ./fryum/normal_png/
# Converted 276.JPG to 276.png and saved to ./fryum/normal_png/
# Converted 277.JPG to 277.png and saved to ./fryum/normal_png/
# Converted 278.JPG to 278.png and saved to ./fryum/normal_png/
# Converted 279.JPG to 279.png and saved to ./fryum/normal_png/
# Converted 280.JPG to 280.png and saved to ./fryum/normal_png/
# Converted 281.JPG to 281.png and saved to ./fryum/normal_png/
# Converted 282.JPG to 282.png and saved to ./fryum/normal_png/
# Converted 283.JPG to 283.png and saved to ./fryum/normal_png/
# Converted 284.JPG to 284.png and saved to ./fryum/normal_png/
# Converted 285.JPG to 285.png and saved to ./fryum/normal_png/
# Converted 286.JPG to 286.png and saved to ./fryum/normal_png/
# Converted 287.JPG to 287.png and saved to ./fryum/normal_png/
# Converted 288.JPG to 288.png and saved to ./fryum/normal_png/
# Converted 289.JPG to 289.png and saved to ./fryum/normal_png/
# Converted 290.JPG to 290.png and saved to ./fryum/normal_png/
# Converted 291.JPG to 291.png and saved to ./fryum/normal_png/
# Converted 292.JPG to 292.png and saved to ./fryum/normal_png/
# Converted 293.JPG to 293.png and saved to ./fryum/normal_png/
# Converted 294.JPG to 294.png and saved to ./fryum/normal_png/
# Converted 295.JPG to 295.png and saved to ./fryum/normal_png/
# Converted 296.JPG to 296.png and saved to ./fryum/normal_png/
# Converted 297.JPG to 297.png and saved to ./fryum/normal_png/
# Converted 298.JPG to 298.png and saved to ./fryum/normal_png/
# Converted 299.JPG to 299.png and saved to ./fryum/normal_png/
# Converted 300.JPG to 300.png and saved to ./fryum/normal_png/
# Converted 301.JPG to 301.png and saved to ./fryum/normal_png/
# Converted 302.JPG to 302.png and saved to ./fryum/normal_png/
# Converted 303.JPG to 303.png and saved to ./fryum/normal_png/
# Converted 304.JPG to 304.png and saved to ./fryum/normal_png/
# Converted 305.JPG to 305.png and saved to ./fryum/normal_png/
# Converted 306.JPG to 306.png and saved to ./fryum/normal_png/
# Converted 307.JPG to 307.png and saved to ./fryum/normal_png/
# Converted 308.JPG to 308.png and saved to ./fryum/normal_png/
# Converted 309.JPG to 309.png and saved to ./fryum/normal_png/
# Converted 310.JPG to 310.png and saved to ./fryum/normal_png/
# Converted 311.JPG to 311.png and saved to ./fryum/normal_png/
# Converted 312.JPG to 312.png and saved to ./fryum/normal_png/
# Converted 313.JPG to 313.png and saved to ./fryum/normal_png/
# Converted 314.JPG to 314.png and saved to ./fryum/normal_png/
# Converted 315.JPG to 315.png and saved to ./fryum/normal_png/
# Converted 316.JPG to 316.png and saved to ./fryum/normal_png/
# Converted 317.JPG to 317.png and saved to ./fryum/normal_png/
# Converted 318.JPG to 318.png and saved to ./fryum/normal_png/
# Converted 319.JPG to 319.png and saved to ./fryum/normal_png/
# Converted 320.JPG to 320.png and saved to ./fryum/normal_png/
# Converted 321.JPG to 321.png and saved to ./fryum/normal_png/
# Converted 322.JPG to 322.png and saved to ./fryum/normal_png/
# Converted 323.JPG to 323.png and saved to ./fryum/normal_png/
# Converted 324.JPG to 324.png and saved to ./fryum/normal_png/
# Converted 325.JPG to 325.png and saved to ./fryum/normal_png/
# Converted 326.JPG to 326.png and saved to ./fryum/normal_png/
# Converted 327.JPG to 327.png and saved to ./fryum/normal_png/
# Converted 328.JPG to 328.png and saved to ./fryum/normal_png/
# Converted 329.JPG to 329.png and saved to ./fryum/normal_png/
# Converted 330.JPG to 330.png and saved to ./fryum/normal_png/
# Converted 331.JPG to 331.png and saved to ./fryum/normal_png/
# Converted 332.JPG to 332.png and saved to ./fryum/normal_png/
# Converted 333.JPG to 333.png and saved to ./fryum/normal_png/
# Converted 334.JPG to 334.png and saved to ./fryum/normal_png/
# Converted 335.JPG to 335.png and saved to ./fryum/normal_png/
# Converted 336.JPG to 336.png and saved to ./fryum/normal_png/
# Converted 337.JPG to 337.png and saved to ./fryum/normal_png/
# Converted 338.JPG to 338.png and saved to ./fryum/normal_png/
# Converted 339.JPG to 339.png and saved to ./fryum/normal_png/
# Converted 340.JPG to 340.png and saved to ./fryum/normal_png/
# Converted 341.JPG to 341.png and saved to ./fryum/normal_png/
# Converted 342.JPG to 342.png and saved to ./fryum/normal_png/
# Converted 343.JPG to 343.png and saved to ./fryum/normal_png/
# Converted 344.JPG to 344.png and saved to ./fryum/normal_png/
# Converted 345.JPG to 345.png and saved to ./fryum/normal_png/
# Converted 346.JPG to 346.png and saved to ./fryum/normal_png/
# Converted 347.JPG to 347.png and saved to ./fryum/normal_png/
# Converted 348.JPG to 348.png and saved to ./fryum/normal_png/
# Converted 349.JPG to 349.png and saved to ./fryum/normal_png/
# Converted 350.JPG to 350.png and saved to ./fryum/normal_png/
# Converted 351.JPG to 351.png and saved to ./fryum/normal_png/
# Converted 352.JPG to 352.png and saved to ./fryum/normal_png/
# Converted 353.JPG to 353.png and saved to ./fryum/normal_png/
# Converted 354.JPG to 354.png and saved to ./fryum/normal_png/
# Converted 355.JPG to 355.png and saved to ./fryum/normal_png/
# Converted 356.JPG to 356.png and saved to ./fryum/normal_png/
# Converted 357.JPG to 357.png and saved to ./fryum/normal_png/
# Converted 358.JPG to 358.png and saved to ./fryum/normal_png/
# Converted 359.JPG to 359.png and saved to ./fryum/normal_png/
# Converted 360.JPG to 360.png and saved to ./fryum/normal_png/
# Converted 361.JPG to 361.png and saved to ./fryum/normal_png/
# Converted 362.JPG to 362.png and saved to ./fryum/normal_png/
# Converted 363.JPG to 363.png and saved to ./fryum/normal_png/
# Converted 364.JPG to 364.png and saved to ./fryum/normal_png/
# Converted 365.JPG to 365.png and saved to ./fryum/normal_png/
# Converted 366.JPG to 366.png and saved to ./fryum/normal_png/
# Converted 367.JPG to 367.png and saved to ./fryum/normal_png/
# Converted 368.JPG to 368.png and saved to ./fryum/normal_png/
# Converted 369.JPG to 369.png and saved to ./fryum/normal_png/
# Converted 370.JPG to 370.png and saved to ./fryum/normal_png/
# Converted 371.JPG to 371.png and saved to ./fryum/normal_png/
# Converted 372.JPG to 372.png and saved to ./fryum/normal_png/
# Converted 373.JPG to 373.png and saved to ./fryum/normal_png/
# Converted 374.JPG to 374.png and saved to ./fryum/normal_png/
# Converted 375.JPG to 375.png and saved to ./fryum/normal_png/
# Converted 376.JPG to 376.png and saved to ./fryum/normal_png/
# Converted 377.JPG to 377.png and saved to ./fryum/normal_png/
# Converted 378.JPG to 378.png and saved to ./fryum/normal_png/
# Converted 379.JPG to 379.png and saved to ./fryum/normal_png/
# Converted 380.JPG to 380.png and saved to ./fryum/normal_png/
# Converted 381.JPG to 381.png and saved to ./fryum/normal_png/
# Converted 382.JPG to 382.png and saved to ./fryum/normal_png/
# Converted 383.JPG to 383.png and saved to ./fryum/normal_png/
# Converted 384.JPG to 384.png and saved to ./fryum/normal_png/
# Converted 385.JPG to 385.png and saved to ./fryum/normal_png/
# Converted 386.JPG to 386.png and saved to ./fryum/normal_png/
# Converted 387.JPG to 387.png and saved to ./fryum/normal_png/
# Converted 388.JPG to 388.png and saved to ./fryum/normal_png/
# Converted 389.JPG to 389.png and saved to ./fryum/normal_png/
# Converted 390.JPG to 390.png and saved to ./fryum/normal_png/
# Converted 391.JPG to 391.png and saved to ./fryum/normal_png/
# Converted 392.JPG to 392.png and saved to ./fryum/normal_png/
# Converted 393.JPG to 393.png and saved to ./fryum/normal_png/
# Converted 394.JPG to 394.png and saved to ./fryum/normal_png/
# Converted 395.JPG to 395.png and saved to ./fryum/normal_png/
# Converted 396.JPG to 396.png and saved to ./fryum/normal_png/
# Converted 397.JPG to 397.png and saved to ./fryum/normal_png/
# Converted 398.JPG to 398.png and saved to ./fryum/normal_png/
# Converted 399.JPG to 399.png and saved to ./fryum/normal_png/
# Converted 400.JPG to 400.png and saved to ./fryum/normal_png/
# Converted 401.JPG to 401.png and saved to ./fryum/normal_png/
# Converted 402.JPG to 402.png and saved to ./fryum/normal_png/
# Converted 403.JPG to 403.png and saved to ./fryum/normal_png/
# Converted 404.JPG to 404.png and saved to ./fryum/normal_png/
# Converted 405.JPG to 405.png and saved to ./fryum/normal_png/
# Converted 406.JPG to 406.png and saved to ./fryum/normal_png/
# Converted 407.JPG to 407.png and saved to ./fryum/normal_png/
# Converted 408.JPG to 408.png and saved to ./fryum/normal_png/
# Converted 409.JPG to 409.png and saved to ./fryum/normal_png/
# Converted 410.JPG to 410.png and saved to ./fryum/normal_png/
# Converted 411.JPG to 411.png and saved to ./fryum/normal_png/
# Converted 412.JPG to 412.png and saved to ./fryum/normal_png/
# Converted 413.JPG to 413.png and saved to ./fryum/normal_png/
# Converted 414.JPG to 414.png and saved to ./fryum/normal_png/
# Converted 415.JPG to 415.png and saved to ./fryum/normal_png/
# Converted 416.JPG to 416.png and saved to ./fryum/normal_png/
# Converted 417.JPG to 417.png and saved to ./fryum/normal_png/
# Converted 418.JPG to 418.png and saved to ./fryum/normal_png/
# Converted 419.JPG to 419.png and saved to ./fryum/normal_png/
# Converted 420.JPG to 420.png and saved to ./fryum/normal_png/
# Converted 421.JPG to 421.png and saved to ./fryum/normal_png/
# Converted 422.JPG to 422.png and saved to ./fryum/normal_png/
# Converted 423.JPG to 423.png and saved to ./fryum/normal_png/
# Converted 424.JPG to 424.png and saved to ./fryum/normal_png/
# Converted 425.JPG to 425.png and saved to ./fryum/normal_png/
# Converted 426.JPG to 426.png and saved to ./fryum/normal_png/
# Converted 427.JPG to 427.png and saved to ./fryum/normal_png/
# Converted 428.JPG to 428.png and saved to ./fryum/normal_png/
# Converted 429.JPG to 429.png and saved to ./fryum/normal_png/
# Converted 430.JPG to 430.png and saved to ./fryum/normal_png/
# Converted 431.JPG to 431.png and saved to ./fryum/normal_png/
# Converted 432.JPG to 432.png and saved to ./fryum/normal_png/
# Converted 433.JPG to 433.png and saved to ./fryum/normal_png/
# Converted 434.JPG to 434.png and saved to ./fryum/normal_png/
# Converted 435.JPG to 435.png and saved to ./fryum/normal_png/
# Converted 436.JPG to 436.png and saved to ./fryum/normal_png/
# Converted 437.JPG to 437.png and saved to ./fryum/normal_png/
# Converted 438.JPG to 438.png and saved to ./fryum/normal_png/
# Converted 439.JPG to 439.png and saved to ./fryum/normal_png/
# Converted 440.JPG to 440.png and saved to ./fryum/normal_png/
# Converted 441.JPG to 441.png and saved to ./fryum/normal_png/
# Converted 442.JPG to 442.png and saved to ./fryum/normal_png/
# Converted 443.JPG to 443.png and saved to ./fryum/normal_png/
# Converted 444.JPG to 444.png and saved to ./fryum/normal_png/
# Converted 445.JPG to 445.png and saved to ./fryum/normal_png/
# Converted 446.JPG to 446.png and saved to ./fryum/normal_png/
# Converted 447.JPG to 447.png and saved to ./fryum/normal_png/
# Converted 448.JPG to 448.png and saved to ./fryum/normal_png/
# Converted 449.JPG to 449.png and saved to ./fryum/normal_png/
# Converted 450.JPG to 450.png and saved to ./fryum/normal_png/
# Converted 451.JPG to 451.png and saved to ./fryum/normal_png/
# Converted 452.JPG to 452.png and saved to ./fryum/normal_png/
# Converted 453.JPG to 453.png and saved to ./fryum/normal_png/
# Converted 454.JPG to 454.png and saved to ./fryum/normal_png/
# Converted 455.JPG to 455.png and saved to ./fryum/normal_png/
# Converted 456.JPG to 456.png and saved to ./fryum/normal_png/
# Converted 457.JPG to 457.png and saved to ./fryum/normal_png/
# Converted 458.JPG to 458.png and saved to ./fryum/normal_png/
# Converted 459.JPG to 459.png and saved to ./fryum/normal_png/
# Converted 460.JPG to 460.png and saved to ./fryum/normal_png/
# Converted 461.JPG to 461.png and saved to ./fryum/normal_png/
# Converted 462.JPG to 462.png and saved to ./fryum/normal_png/
# Converted 463.JPG to 463.png and saved to ./fryum/normal_png/
# Converted 464.JPG to 464.png and saved to ./fryum/normal_png/
# Converted 465.JPG to 465.png and saved to ./fryum/normal_png/
# Converted 466.JPG to 466.png and saved to ./fryum/normal_png/
# Converted 467.JPG to 467.png and saved to ./fryum/normal_png/
# Converted 468.JPG to 468.png and saved to ./fryum/normal_png/
# Converted 469.JPG to 469.png and saved to ./fryum/normal_png/
# Converted 470.JPG to 470.png and saved to ./fryum/normal_png/
# Converted 471.JPG to 471.png and saved to ./fryum/normal_png/
# Converted 472.JPG to 472.png and saved to ./fryum/normal_png/
# Converted 473.JPG to 473.png and saved to ./fryum/normal_png/
# Converted 474.JPG to 474.png and saved to ./fryum/normal_png/
# Converted 475.JPG to 475.png and saved to ./fryum/normal_png/
# Converted 476.JPG to 476.png and saved to ./fryum/normal_png/
# Converted 477.JPG to 477.png and saved to ./fryum/normal_png/
# Converted 478.JPG to 478.png and saved to ./fryum/normal_png/
# Converted 479.JPG to 479.png and saved to ./fryum/normal_png/
# Converted 480.JPG to 480.png and saved to ./fryum/normal_png/
# Converted 481.JPG to 481.png and saved to ./fryum/normal_png/
# Converted 482.JPG to 482.png and saved to ./fryum/normal_png/
# Converted 483.JPG to 483.png and saved to ./fryum/normal_png/
# Converted 484.JPG to 484.png and saved to ./fryum/normal_png/
# Converted 485.JPG to 485.png and saved to ./fryum/normal_png/
# Converted 486.JPG to 486.png and saved to ./fryum/normal_png/
# Converted 487.JPG to 487.png and saved to ./fryum/normal_png/
# Converted 488.JPG to 488.png and saved to ./fryum/normal_png/
# Converted 489.JPG to 489.png and saved to ./fryum/normal_png/
# Converted 490.JPG to 490.png and saved to ./fryum/normal_png/
# Converted 491.JPG to 491.png and saved to ./fryum/normal_png/
# Converted 492.JPG to 492.png and saved to ./fryum/normal_png/
# Converted 493.JPG to 493.png and saved to ./fryum/normal_png/
# Converted 494.JPG to 494.png and saved to ./fryum/normal_png/
# Converted 495.JPG to 495.png and saved to ./fryum/normal_png/
# Converted 496.JPG to 496.png and saved to ./fryum/normal_png/
# Converted 497.JPG to 497.png and saved to ./fryum/normal_png/
# Converted 498.JPG to 498.png and saved to ./fryum/normal_png/
# Converted 499.JPG to 499.png and saved to ./fryum/normal_png/

# %% [markdown]
# ## Dataset: fryum

# %%
from anomalib.data.folder import Folder
from anomalib.data.task_type import TaskType

datamodule = Folder(
    root=Path.cwd() / "fryum",
    normal_dir="normal_png",
    abnormal_dir="anomaly_png",
    normal_split_ratio=0.2,
    image_size=(256, 256),
    train_batch_size=32,
    eval_batch_size=32,
    task=TaskType.CLASSIFICATION,
)
datamodule.setup()  # Split the data to train/val/test/prediction sets.
datamodule.prepare_data()  # Create train/val/test/predic dataloaders

i, data = next(enumerate(datamodule.val_dataloader()))
print(data.keys())
# Out:
# dict_keys(['image_path', 'label', 'image'])

# %%
# Check image size
print(data["image"].shape)
# Out:
# torch.Size([32, 3, 256, 256])

# %% [markdown]
# # Model: Padim, Backbone: ResNet-18

# %% [markdown]
# ## Prepare the Model

# %%
from anomalib.models import Padim

model = Padim(
    input_size=(256, 256),
    backbone="resnet18",
    layers=["layer1", "layer2", "layer3"],
)
# Out:
# C:\Users\rozzb\mambaforge\envs\nlp\lib\site-packages\torchmetrics\utilities\prints.py:36: DeprecationWarning: From v0.10 an `'Binary*'`, `'Multiclass*', `'Multilabel*'` version now exist of each classification metric. Moving forward we recommend using these versions. This base metric will still work as it did prior to v0.10 until v0.11. From v0.11 the `task` argument introduced in this metric will be required and the general order of arguments may change, such that this metric will just function as an single entrypoint to calling the three specialized versions.
#   warnings.warn(*args, **kwargs)
# C:\Users\rozzb\mambaforge\envs\nlp\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# FeatureExtractor is deprecated. Use TimmFeatureExtractor instead. Both FeatureExtractor and TimmFeatureExtractor will be removed in a future release.

# %% [markdown]
# ## Prepare Callbacks

# %%
from anomalib.post_processing import NormalizationMethod, ThresholdMethod
from anomalib.utils.callbacks import (
    MetricsConfigurationCallback,
    MinMaxNormalizationCallback,
    PostProcessingConfigurationCallback,
)
from anomalib.utils.callbacks.export import ExportCallback, ExportMode

callbacks = [
    MetricsConfigurationCallback(
        task=TaskType.CLASSIFICATION,
        image_metrics=["AUROC", "AUPR"],
    ),
    ModelCheckpoint(
        mode="max",
        monitor="image_AUROC",
    ),
    PostProcessingConfigurationCallback(
        normalization_method=NormalizationMethod.MIN_MAX,
        threshold_method=ThresholdMethod.ADAPTIVE,
    ),
    MinMaxNormalizationCallback(),
    ExportCallback(
        input_size=(256, 256),
        dirpath=str(Path.cwd()),
        filename="model",
        export_mode=ExportMode.OPENVINO,
    ),
]

# %% [markdown]
# ## Training

# %%
trainer = Trainer(
    callbacks=callbacks,
    accelerator="auto",
    auto_scale_batch_size=False,
    check_val_every_n_epoch=1,
    devices=1,
    gpus=None,
    max_epochs=10,
    num_sanity_val_steps=0,
    val_check_interval=1.0,
)
trainer.fit(model=model, datamodule=datamodule)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# Missing logger folder: C:\Users\rozzb\ML3\Final Project\Fryum_padim\lightning_logs
# C:\Users\rozzb\mambaforge\envs\nlp\lib\site-packages\torchmetrics\utilities\prints.py:36: DeprecationWarning: From v0.10 an `'Binary*'`, `'Multiclass*', `'Multilabel*'` version now exist of each classification metric. Moving forward we recommend using these versions. This base metric will still work as it did prior to v0.10 until v0.11. From v0.11 the `task` argument introduced in this metric will be required and the general order of arguments may change, such that this metric will just function as an single entrypoint to calling the three specialized versions.
#   warnings.warn(*args, **kwargs)
# C:\Users\rozzb\mambaforge\envs\nlp\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# C:\Users\rozzb\mambaforge\envs\nlp\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# C:\Users\rozzb\mambaforge\envs\nlp\lib\site-packages\pytorch_lightning\core\optimizer.py:183: UserWarning: `LightningModule.configure_optimizers` returned `None`, this fit will run with no optimizer
#   rank_zero_warn(
#
#   | Name                  | Type                     | Params
# -------------------------------------------------------------------
# 0 | image_threshold       | AnomalyScoreThreshold    | 0
# 1 | pixel_threshold       | AnomalyScoreThreshold    | 0
# 2 | model                 | PadimModel               | 2.8 M
# 3 | image_metrics         | AnomalibMetricCollection | 0
# 4 | pixel_metrics         | AnomalibMetricCollection | 0
# 5 | normalization_metrics | MinMax                   | 0
# -------------------------------------------------------------------
# 2.8 M     Trainable params
# 0         Non-trainable params
# 2.8 M     Total params
# 11.131    Total estimated model params size (MB)
# C:\Users\rozzb\mambaforge\envs\nlp\lib\site-packages\torch\utils\tensorboard\__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(
# C:\Users\rozzb\mambaforge\envs\nlp\lib\site-packages\pytorch_lightning\trainer\trainer.py:1609: PossibleUserWarning: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# C:\Users\rozzb\mambaforge\envs\nlp\lib\site-packages\pytorch_lightning\loops\optimization\optimizer_loop.py:138: UserWarning: `training_step` returned `None`. If this was on purpose, ignore this warning...
#   self.warning_cache.warn("`training_step` returned `None`. If this was on purpose, ignore this warning...")
# Validation: 0it [00:00, ?it/s]
# C:\Users\rozzb\mambaforge\envs\nlp\lib\site-packages\torchmetrics\utilities\prints.py:36: DeprecationWarning: `torchmetrics.functional.auc` has been move to `torchmetrics.utilities.compute` in v0.10 and will be removed in v0.11.
#   warnings.warn(*args, **kwargs)
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# C:\Users\rozzb\mambaforge\envs\nlp\lib\site-packages\torch\onnx\_internal\jit_utils.py:306: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\jit\passes\onnx\constant_fold.cpp:181.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# C:\Users\rozzb\mambaforge\envs\nlp\lib\site-packages\torch\onnx\utils.py:689: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\jit\passes\onnx\constant_fold.cpp:181.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# C:\Users\rozzb\mambaforge\envs\nlp\lib\site-packages\torch\onnx\utils.py:1186: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\jit\passes\onnx\constant_fold.cpp:181.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# ================ Diagnostic Run torch.onnx.export version 2.0.0 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %% [markdown]
# ## Evaluation

# %%
# Validation
test_results = trainer.test(model=model, datamodule=datamodule)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUPR         │    0.9020532369613647     │
# │        image_AUROC        │    0.8984000086784363     │
# └───────────────────────────┴───────────────────────────┘

# %% [markdown]
# ## Inference using OpenVino

# %% [markdown]
# ### Load a Test Image

# %%
from matplotlib import pyplot as plt

image_path = "./fryum/anomaly_png/046.png"
image = read_image(path="./fryum/anomaly_png/046.png")
plt.imshow(image)

# %% [markdown]
# ### Load the OpenVINO Model

# %%
openvino_model_path = Path.cwd() / "weights" / "openvino" / "model.bin"
metadata_path = Path.cwd() / "weights" / "openvino" / "metadata.json"
print(openvino_model_path.exists(), metadata_path.exists())
# Out:
# True True

# %%
inferencer = OpenVINOInferencer(
    path=openvino_model_path,  # Path to the OpenVINO IR model.
    metadata=metadata_path,  # Path to the metadata file.
    device="CPU",  # We would like to run it on an Intel CPU.
)

# %% [markdown]
# ### Perform Inference

# %%
print(image.shape)
predictions = inferencer.predict(image=image)
# Out:
# (1000, 1500, 3)

# %% [markdown]
# ### Visualizing Inference Results

# %% [markdown]
# #### Example 1

# %%
from anomalib.post_processing import Visualizer, VisualizationMode
from PIL import Image

visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.CLASSIFICATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x500>

# %%
visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.SEGMENTATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x500>

# %% [markdown]
# #### Example 2

# %%
image = read_image(path="./fryum/anomaly_png/009.png")
predictions = inferencer.predict(image=image)
visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.CLASSIFICATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x500>

# %%
visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.SEGMENTATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x500>

# %% [markdown]
# #### Example 3

# %%
image = read_image(path="./fryum/anomaly_png/053.png")
predictions = inferencer.predict(image=image)
visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.CLASSIFICATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x500>

# %%
visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.SEGMENTATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x500>

# %% [markdown]
# #### Example 4

# %%
image = read_image(path="./fryum/anomaly_png/003.png")
predictions = inferencer.predict(image=image)
visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.CLASSIFICATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x500>

# %%
visualizer = Visualizer(mode=VisualizationMode.FULL, task=TaskType.SEGMENTATION)
output_image = visualizer.visualize_image(predictions)
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x500>
